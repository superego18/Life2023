# %%
import concurrent.futures
import math

# %%
PRIMES = [
    112272535095293,
    112582705942171,
    112272535095293,
    115280095190773,
    115797848077099,
    1099726899285419]

def is_prime(n):
    if n % 2 == 0:
        return False

    sqrt_n = int(math.floor(math.sqrt(n)))
    for i in range(3, sqrt_n + 1, 2):
        if n % i == 0:
            return False
    return True

def main():
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for number, prime in zip(PRIMES, executor.map(is_prime, PRIMES)):
            print('%d is prime: %s' % (number, prime))

if __name__ == '__main__':
    main()
# Out:
# 112272535095293 is prime: True
# 112582705942171 is prime: True
# 112272535095293 is prime: True
# 115280095190773 is prime: True
# 115797848077099 is prime: True
# 1099726899285419 is prime: False

# %%
import time

def main():
    print("병렬처리 시작")
    start = time.time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=None) as executor:
        for number, prime in zip(PRIMES, executor.map(is_prime, PRIMES)):
            print('%d is prime: %s' % (number, prime))
    end = time.time()
    print("병렬처리 수행 시각", end-start, 's')

    start = time.time()
    for number, prime in zip(PRIMES, map(is_prime, PRIMES)):
        print('%d is prime: %s' % (number, prime))
    end = time.time()
    print("단일처리 수행 시각", end-start, 's')

# %%
if __name__ == '__main__':
    main()
# Out:
# 병렬처리 시작
# 112272535095293 is prime: True
# 112582705942171 is prime: True
# 112272535095293 is prime: True
# 115280095190773 is prime: True
# 115797848077099 is prime: True
# 1099726899285419 is prime: False
# 병렬처리 수행 시각 1.6510310173034668 s
# 112272535095293 is prime: True
# 112582705942171 is prime: True
# 112272535095293 is prime: True
# 115280095190773 is prime: True
# 115797848077099 is prime: True
# 1099726899285419 is prime: False
# 단일처리 수행 시각 1.6259403228759766 s

# %%
import concurrent.futures
import urllib.request

URLS = ['http://www.foxnews.com/',
        'http://www.cnn.com/',
        'http://europe.wsj.com/',
        'http://www.bbc.co.uk/',
        'http://nonexistant-subdomain.python.org/']

# Retrieve a single page and report the URL and contents
def load_url(url, timeout):
    with urllib.request.urlopen(url, timeout=timeout) as conn:
        return conn.read()

# We can use a with statement to ensure threads are cleaned up promptly
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Start the load operations and mark each future with its URL
    future_to_url = {executor.submit(load_url, url, 60): url for url in URLS}
    for future in concurrent.futures.as_completed(future_to_url):
        url = future_to_url[future]
        try:
            data = future.result()
        except Exception as exc:
            print('%r generated an exception: %s' % (url, exc))
        else:
            print('%r page is %d bytes' % (url, len(data)))
# Out:
# 'http://nonexistant-subdomain.python.org/' generated an exception: <urlopen error [Errno 11001] getaddrinfo failed>
# 'http://www.cnn.com/' page is 2501316 bytes
# 'http://www.foxnews.com/' page is 558153 bytes
# 'http://www.bbc.co.uk/' page is 541729 bytes
# 'http://europe.wsj.com/' generated an exception: HTTP Error 403: Forbidden

# %%
import concurrent.futures
import math

PRIMES = [
    112272535095293,
    112582705942171,
    112272535095293,
    115280095190773,
    115797848077099,
    1099726899285419]

def is_prime(n):
    if n < 2:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False

    sqrt_n = int(math.floor(math.sqrt(n)))
    for i in range(3, sqrt_n + 1, 2):
        if n % i == 0:
            return False
    return True

def main():
    with concurrent.futures.ProcessPoolExecutor() as executor:
        for number, prime in zip(PRIMES, executor.map(is_prime, PRIMES)):
            print('%d is prime: %s' % (number, prime))

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[2], line 32
#      29             print('%d is prime: %s' % (number, prime))
#      31 if __name__ == '__main__':
# ---> 32     main()
#
# Cell In[2], line 28, in main()
#      26 def main():
#      27     with concurrent.futures.ProcessPoolExecutor() as executor:
# ---> 28         for number, prime in zip(PRIMES, executor.map(is_prime, PRIMES)):
#      29             print('%d is prime: %s' % (number, prime))
#
# File ~\anaconda3\lib\concurrent\futures\process.py:570, in _chain_from_iterable_of_lists(iterable)
#     564 def _chain_from_iterable_of_lists(iterable):
#     565     """
#     566     Specialized implementation of itertools.chain.from_iterable.
#     567     Each item in *iterable* should be a list.  This function is
#     568     careful not to keep references to yielded objects.
#     569     """
# --> 570     for element in iterable:
#     571         element.reverse()
#     572         while element:
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~\anaconda3\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
import itertools

st = time.time()
list1 = ['a', 'b', 'c'] *100
list2 = ['d', 'e', 'f'] * 100

# Generate all combinations of elements from list1 and list2
combinations = set(itertools.product(list1, list2))

# Filter out combinations where 'crab' is present in both lists
filtered_combinations = [combo for combo in tqdm(combinations) if 'crab' not in combo]

# Print the filtered combinations
for combo in filtered_combinations:
    print(combo)
ed = time.time()
print(ed-st)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<?, ?it/s]
# ('c', 'f')
# ('a', 'f')
# ('b', 'f')
# ('c', 'd')
# ('c', 'e')
# ('a', 'e')
# ('a', 'd')
# ('b', 'e')
# ('b', 'd')
# 0.005475282669067383

# %%
print(combinations)
# Out:
# [('a', 'd'), ('a', 'e'), ('a', 'f'), ('b', 'd'), ('b', 'e'), ('b', 'f'), ('c', 'd'), ('c', 'e'), ('c', 'f')]

# %%
import time

# %%
from tqdm import tqdm

# %%
import pandas as pd

# %%
import os

folder_path = 'datasets-KOSDAQ'  # Replace with the actual folder path

file_names = []  # Initialize an empty list to store the file names

for file_name in tqdm(os.listdir(folder_path)):
    if os.path.isfile(os.path.join(folder_path, file_name)):
        file_names.append(file_name[-13:-4])

print(file_names)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████|
S', '036190 KS', '036200 KS', '036480 KS', '036540 KS', '036560 KS', '036620 KS', '036630 KS', '036640 KS', '036670 KS', '036690 KS', '036710 KS', '036800 KS', '036810 KS', '036830 KS', '036890 KS', '036930 KS', '037030 KS', '037070 KS', '037230 KS', '037330 KS', '037350 KS', '037370 KS', '037400 KS', '037440 KS', '037460 KS', '037760 KS', '037950 KS', '038010 KS', '038060 KS', '038070 KS', '038110 KS', '038290 KS', '038340 KS', '038390 KS', '038460 KS', '038500 KS', '038530 KS', '038540 KS', '038620 KS', '038680 KS', '038870 KS', '038880 KS', '038950 KS', '039010 KS', '039020 KS', '039030 KS', '039200 KS', '039240 KS', '039290 KS', '039310 KS', '039340 KS', '039420 KS', '039440 KS', '039560 KS', '039610 KS', '039740 KS', '039830 KS', '039840 KS', '039860 KS', '039980 KS', '040160 KS', '040300 KS', '040350 KS', '040420 KS', '040610 KS', '040910 KS', '041020 KS', '041190 KS', '041440 KS', '041460 KS', '041510 KS', '041520 KS', '041590 KS', '041830 KS', '041910 KS', '041920 KS', '041930 KS', '041960 KS', '042000 KS', '042040 KS', '042110 KS', '042370  ...

# %%
kosdaq = pd.DataFrame()

# %%
kosdaq['ticker_bloomberg'] = file_names

# %%
kosdaq['ticker_DB'] = [x.replace(' ', '_') for x in kosdaq['ticker_bloomberg']]

# %%
kosdaq
# Out:
#      ticker_bloomberg  ticker_DB
# 0           000250 KS  000250_KS
# 1           000440 KS  000440_KS
# 2           001000 KS  001000_KS
# 3           001540 KS  001540_KS
# 4           001810 KS  001810_KS
# ...               ...        ...
# 1618        448830 KS  448830_KS
# 1619        449020 KS  449020_KS
# 1620        450050 KS  450050_KS
# 1621        450410 KS  450410_KS
# 1622        451700 KS  451700_KS
#
# [1623 rows x 2 columns]

# %%
kosdq_mems = [x[:-3] for x in kosdaq['ticker_bloomberg']]

# %%
kosdq_mems
# Out:
# ['000250',
#  '000440',
#  '001000',
#  '001540',
#  '001810',
#  '001840',
#  '002230',
#  '002290',
#  '002680',
#  '002800',
#  '003100',
#  '003310',
#  '003380',
#  '003800',
#  '004590',
#  '004650',
#  '004780',
#  '005160',
#  '005290',
#  '005670',
#  '005710',
#  '005860',
#  '005990',
#  '006050',
#  '006140',
#  '006580',
#  '006620',
#  '006730',
#  '006910',
#  '006920',
#  '007330',
#  '007370',
#  '007390',
#  '007530',
#  '007680',
#  '007720',
#  '007770',
#  '007820',
#  '008290',
#  '008370',
#  '008470',
#  '008830',
#  '009300',
#  '009520',
#  '009620',
#  '009730',
#  '009780',
#  '010170',
#  '010240',
#  '010280',
#  '010470',
#  '011040',
#  '011080',
#  '011320',
#  '011370',
#  '011560',
#  '012340',
#  '012620',
#  '012700',
#  '012790',
#  '012860',
#  '013030',
#  '013120',
#  '013310',
#  '013720',
#  '013810',
#  '013990',
#  '014100',
#  '014190',
#  '014200',
#  '014470',
#  '014570',
#  '014620',
#  '014940',
#  '014970',
#  '015710',
#  '015750',
#  '016100',
#  '016250',
#  '016600',
#  '016670',
#  '016790',
#  '016920',
#  '151910',
#  '153460',
#  '153490',
#  '153710',
#  '154030',
#  '154040',
#  '155650',
#  '156100',
#  '158430',
#  '159010',
#  '159580',
#  '159910',
#  '160550',
#  '160600',
#  '160980',
#  '161570',
#  '161580',
#  '162300',
#  '163730',
#  '164060',
#  '166090',
#  '166480',
#  '168330',
#  '168360',
#  '169330',
#  '170030',
#  '170790',
#  '170920',
#  '171010',
#  '171090',
#  '171120',
#  '173130',
#  '173940',
#  '174880',
#  '174900',
#  '175140',
#  '175250',
#  ...]

# %%
def get_company_info(ticker):
    url = f"https://stockmarketmba.com/analyze.php?s=KQ:{ticker}"
    response = requests.get(url)
    html_text = BeautifulSoup(response.content, 'html.parser').prettify()

    sector_match = re.search(r"GICS sector:\s+([^\<]+)", str(html_text))

    try:
        name_element = BeautifulSoup(html_text, 'html.parser').find('h3').find_next('a')
    
    except:
        name_element = None
        
    if name_element:
        name = name_element.find_next_sibling(text=True).strip()
        name = html.unescape(name)
    else:
        name = None
    
    if sector_match:
        sector = sector_match.group(1).strip()
        sector = html.unescape(sector)
    else:
        sector = None

    return name, sector

# %%
from joblib import Parallel, delayed

# %%
import requests
import html
from bs4 import BeautifulSoup
import re

# %%
with Parallel(n_jobs = 12) as parallel:
    results = parallel(delayed(get_company_info)(ticker) for ticker in tqdm(kosdq_mems))
# Out:
#   0%|                                                                                         | 0/1623 [00:00<?, ?it/s]
#
#
#
#   1%|█▏                                                                              | 24/1623 [00:04<04:44,  5.62it/s]
#
#
#
#   2%|█▊                                                                              | 36/1623 [00:07<05:28,  4.83it/s]
#
#
#
#   3%|██▎                                                                             | 48/1623 [00:11<06:52,  3.82it/s]
#
#
#
#   4%|██▉                                                                             | 60/1623 [00:14<06:43,  3.87it/s]
#
#
#
#   4%|███▌                                                                            | 72/1623 [00:17<06:22,  4.05it/s]
#
#
#
#   5%|████▏                                                                           | 84/1623 [00:19<06:11,  4.15it/s]
#
#
#
#   6%|████▋                                                                           | 96/1623 [00:22<05:53,  4.32it/s]
#
#
#
#   7%|█████▎                                                                         | 108/1623 [00:24<05:29,  4.59it/s]
#
#
#
#   7%|█████▊                                                                         | 120/1623 [00:27<05:24,  4.63it/s]
#
#
#
#   8%|██████▍                                                                        | 132/1623 [00:30<05:27,  4.55it/s]
#
#
#
#   9%|███████                                                                        | 144/1623 [00:33<05:42,  4.32it/s]
#
#
#
#  10%|███████▌                                                                       | 156/1623 [00:36<05:46,  4.24it/s]
#
#
#
#  10%|████████▏                                                                      | 168/1623 [00:38<05:45,  4.22it/s]
#
#
#
#  11%|████████▊                                                                      | 180/1623 [00:41<05:48,  4.14it/s]
#
#
#
#  12%|█████████▎                                                                     | 192/1623 [00:44<05:33,  4.29it/s]
#
#
#
#  13%|█████████▉                                                                     | 204/1623 [00:47<05:33,  4.26it/s]
#
#
#
#  13%|██████████▌                                                                    | 216/1623 [00:50<05:29,  4.26it/s]
#
#
#
#  14%|███████████                                                                    | 228/1623 [00:52<05:24,  4.30it/s]
#
#
#
#  82%|████████████████████████████████████████████████████████████████              | 1332/1623 [05:14<01:35,  3.03it/s]
#
#
#
#  83%|████████████████████████████████████████████████████████████████▌             | 1344/1623 [05:17<01:26,  3.21it/s]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▏            | 1356/1623 [05:20<01:17,  3.43it/s]
#
#
#
#  84%|█████████████████████████████████████████████████████████████████▋            | 1368/1623 [05:23<01:10,  3.61it/s]
#
#
#
#  85%|██████████████████████████████████████████████████████████████████▎           | 1380/1623 [05:26<01:06,  3.66it/s]
#
#
#
#  86%|██████████████████████████████████████████████████████████████████▉           | 1392/1623 [05:30<01:04,  3.55it/s]
#
#
#
#  87%|███████████████████████████████████████████████████████████████████▍          | 1404/1623 [05:33<00:58,  3.73it/s]
#
#
#
#  87%|████████████████████████████████████████████████████████████████████          | 1416/1623 [05:35<00:50,  4.06it/s]
#
#
#
#  88%|████████████████████████████████████████████████████████████████████▋         | 1428/1623 [05:38<00:48,  4.06it/s]
#
#
#
#  89%|█████████████████████████████████████████████████████████████████████▏        | 1440/1623 [05:40<00:41,  4.38it/s]
#  89%|█████████████████████████████████████████████████████████████████████▊        | 1452/1623 [05:43<00:38,  4.48it/s]
#
#
#
#  90%|██████████████████████████████████████████████████████████████████████▎       | 1464/1623 [05:45<00:35,  4.43it/s]
#
#
#
#  91%|██████████████████████████████████████████████████████████████████████▉       | 1476/1623 [05:49<00:34,  4.23it/s]
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████▌      | 1488/1623 [05:52<00:32,  4.21it/s]
#
#
#
#  92%|████████████████████████████████████████████████████████████████████████      | 1500/1623 [05:54<00:29,  4.15it/s]
#
#
#
#  93%|████████████████████████████████████████████████████████████████████████▋     | 1512/1623 [05:57<00:26,  4.16it/s]
#
#
#
#  94%|█████████████████████████████████████████████████████████████████████████▏    | 1524/1623 [06:00<00:23,  4.24it/s]
#
#
#
#  95%|█████████████████████████████████████████████████████████████████████████▊    | 1536/1623 [06:03<00:20,  4.26it/s]
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████████▍   | 1548/1623 [06:06<00:17,  4.28it/s]
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████████▉   | 1560/1623 [06:10<00:17,  3.57it/s]
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████████▌  | 1572/1623 [06:13<00:13,  3.91it/s]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▏ | 1584/1623 [06:15<00:09,  4.30it/s]
#
#
#
#  98%|████████████████████████████████████████████████████████████████████████████▋ | 1596/1623 [06:17<00:06,  4.50it/s]
#
#
#
#  99%|█████████████████████████████████████████████████████████████████████████████▎| 1608/1623 [06:20<00:03,  4.38it/s]
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████| 1623/1623 [06:23<00:00,  4.23it/s]

# %%
name_list = []
sector_list = []

for i in tqdm(results):
    name_list.append(i[0])
    sector_list.append(i[1])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 1623/1623 [00:00<00:00, 1160872.34it/s]

# %%
kosdaq2 = kosdaq.copy()

# %%
kosdaq
# Out:
#      ticker_bloomberg  ticker_DB                     name  gics_sector
# 0           000250 KS  000250_KS  Sam Chun Dang Pharm Ltd  Health Care
# 1           000440 KS  000440_KS                    tool.         None
# 2           001000 KS  001000_KS                    tool.         None
# 3           001540 KS  001540_KS                    tool.         None
# 4           001810 KS  001810_KS                    tool.         None
# ...               ...        ...                      ...          ...
# 1618        448830 KS  448830_KS                    tool.         None
# 1619        449020 KS  449020_KS                    tool.         None
# 1620        450050 KS  450050_KS                    tool.         None
# 1621        450410 KS  450410_KS                    tool.         None
# 1622        451700 KS  451700_KS                    tool.         None
#
# [1623 rows x 4 columns]

# %%
kosdaq['name'] = name_list
kosdaq['gics_sector'] = sector_list

# %%
other_sector = ['Unknown', 'Communication', 'SEMICONDUCTORS & SEMICONDUCTOR EQUIPMEN', 'Household & Personal Products', 'Technology Hardware & Equipment', 'Other',  'Health Care Equipment & Services', 'Food Beverage & Tobacco']

# %%
error = kosdaq[(kosdaq['name'] == '') | (kosdaq['name'] == 'tool.') | (kosdaq['gics_sector'].isin(other_sector))]

# %%
error
# Out:
#      ticker_bloomberg  ticker_DB   name gics_sector
# 1           000440 KS  000440_KS  tool.        None
# 2           001000 KS  001000_KS  tool.        None
# 3           001540 KS  001540_KS  tool.        None
# 4           001810 KS  001810_KS  tool.        None
# 5           001840 KS  001840_KS  tool.        None
# ...               ...        ...    ...         ...
# 1618        448830 KS  448830_KS  tool.        None
# 1619        449020 KS  449020_KS  tool.        None
# 1620        450050 KS  450050_KS  tool.        None
# 1621        450410 KS  450410_KS  tool.        None
# 1622        451700 KS  451700_KS  tool.        None
#
# [1450 rows x 4 columns]

# %%
error_index = list(error.index)

# %%
error_list = [x[:-3] for x in error['ticker_bloomberg']]

# %%
error_list
# Out:
# ['000440',
#  '001000',
#  '001540',
#  '001810',
#  '001840',
#  '002230',
#  '002290',
#  '002680',
#  '002800',
#  '003100',
#  '003310',
#  '003800',
#  '004590',
#  '004650',
#  '004780',
#  '005160',
#  '005670',
#  '005710',
#  '005860',
#  '006050',
#  '006140',
#  '006580',
#  '006620',
#  '006910',
#  '006920',
#  '007330',
#  '007370',
#  '007530',
#  '007680',
#  '007720',
#  '007770',
#  '007820',
#  '008290',
#  '008370',
#  '008470',
#  '008830',
#  '009300',
#  '009520',
#  '009620',
#  '009730',
#  '009780',
#  '010240',
#  '010280',
#  '010470',
#  '011040',
#  '011080',
#  '011320',
#  '011370',
#  '011560',
#  '012340',
#  '012620',
#  '012700',
#  '012790',
#  '012860',
#  '013310',
#  '013720',
#  '013810',
#  '013990',
#  '014100',
#  '014190',
#  '014200',
#  '014470',
#  '014570',
#  '014940',
#  '014970',
#  '015710',
#  '016250',
#  '016600',
#  '016670',
#  '016790',
#  '016920',
#  '017000',
#  '017250',
#  '017480',
#  '017510',
#  '017650',
#  '017890',
#  '018120',
#  '018290',
#  '018310',
#  '018620',
#  '018680',
#  '018700',
#  '019010',
#  '019210',
#  '019540',
#  '019550',
#  '019570',
#  '019590',
#  '019660',
#  '019770',
#  '019990',
#  '020180',
#  '020400',
#  '020710',
#  '021040',
#  '021080',
#  '021320',
#  '021650',
#  '021880',
#  '022220',
#  '023160',
#  '023440',
#  '023460',
#  '023600',
#  '023760',
#  '023770',
#  '023790',
#  '023900',
#  '023910',
#  '024060',
#  '024120',
#  '024740',
#  '024800',
#  '024810',
#  '024830',
#  '024840',
#  '024850',
#  '024880',
#  '024910',
#  '024940',
#  '024950',
#  '025320',
#  '025440',
#  '025550',
#  '025770',
#  '025870',
#  '025880',
#  '025950',
#  '026040',
#  '026150',
        response = requests.get(url)
        html_text = BeautifulSoup(response.content, 'html.parser').prettify()
        soup = BeautifulSoup(html_text, 'html.parser')

        tbody = soup.find('tbody')

        if tbody:
            tr_elements = tbody.find_all('tr')
            if len(tr_elements) >= 3:
                td_elements = tr_elements[2].find_all('td')
                if len(td_elements) >= 4:
                    desired_element = td_elements[3]
                    name = desired_element.text.strip()
                    if '.,Ltd.' in name:
                        name = name.replace('.,Ltd.', ' Ltd')
                    elif '., Ltd.' in name:
                        name = name.replace('., Ltd.', ' Ltd')
                    elif '., LTD.' in name:
                        name = name.replace('., LTD.', ' Ltd')
                    return name
      
        return None
    
    except:
        return None

# %%
with Parallel(n_jobs = 12) as parallel:
    results = parallel(delayed(get_company_info2)(ticker) for ticker in tqdm(error_list))

# %%
len(results)

# %%
results2 = [x.replace('.,LTD', ' Ltd') if '.,LTD' in x else x for x in results]

# %%
results2 = [x.replace('.,LTD', ' Ltd') if x.isin('.,LTD') else x for x in results]

# %%
results2 = [x.replace('.,LTD', ' Ltd') if '.,LTD' in x else x for x in results]

# %%
results2 = []
for x in results:
    if x is None:
        results2.append(x)
    
    elif '.,LTD' in x:
        results2.append(x.replace('.,LTD', ' Ltd'))
    elif '., Ltd' in x:
        results2.append(x.replace('., Ltd', ' Ltd'))    
    elif '.,LTD' in x:
        results2.append(x.replace('., LTD', ' Ltd'))
    elif '., LTD' in x:
        results2.append(x.replace('., LTD', ' Ltd'))
    else:
        results2.append(x)

# %%
results3 = []
for x in results2:
    if x is None:
        results3.append(x)
    elif x is '':
        results3.append(None)
  
    elif x[-1] is '.':
        results3.append(x[:-1])
    else:
        results3.append(x)

# %%
len(results3)

# %%
results3

# %%
for i, name in zip(error_index, results3):
    kosdaq.iloc[i]['name'] = name

# %%
kosdaq.head(100)
# Out:
#    ticker_bloomberg  ticker_DB                            name  gics_sector
# 0         000250 KS  000250_KS         Sam Chun Dang Pharm Ltd  Health Care
# 1         000440 KS  000440_KS        Joong Ang Enervis Co Ltd         None
# 2         001000 KS  001000_KS                    SillaTextile         None
# 3         001540 KS  001540_KS  AHN-GOOK PHARMACEUTICAL Co Ltd         None
# 4         001810 KS  001810_KS                MOORIM SP CO Ltd         None
# ..              ...        ...                             ...          ...
# 95        018700 KS  018700_KS                        Barunson         None
# 96        019010 KS  019010_KS                   VenueG Co Ltd         None
# 97        019210 KS  019210_KS                     YG-1 CO Ltd         None
# 98        019540 KS  019540_KS          ILJI TECHNOLOGY CO Ltd         None
# 99        019550 KS  019550_KS     SBI Investment KOREA Co Ltd         None
#
# [100 rows x 4 columns]

# %%
kosdaq.to_csv('KOSDAQ_members.csv', index=None)

# %%
sector = [None if x in other_sector else x for x in kosdaq['gics_sector']]

# %%
kosdaq['gics_sector'] = sector

# %%
kosdaq['gics_sector'].value_counts()
# Out:
# Information Technology    68
# Health Care               59
# Materials                 15
# Consumer Staples          13
# Consumer Discretionary    12
# Industrials               10
# Communication Services     4
# Financials                 3
# Real Estate                1
# Name: gics_sector, dtype: int64
