# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.8/44.8 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0

# %%
import pymysql

# %%
con = pymysql.connect(
    user='root',
    passwd='life2023',
    host='127.0.0.1',
    db='shop',
    charset='utf8'
)

mycursor = con.cursor()

# %%
query = """
    insert into goods values ('0009', '스테이플러', '사무용품', '2000', '1500', '2020-12-30');
"""

mycursor.execute(query)
con.commit()
con.close()

# %%
query = """
    select * from goods;
"""

mycursor.execute(query)
data = mycursor.fetchall()
con.close()

display(data)
# Out:
# (('0001', '티셔츠', '의류', 1000, 500, datetime.date(2020, 9, 20)),
#  ('0002', '펀칭기', '사무용품', 500, 320, datetime.date(2020, 9, 11)),
#  ('0003', '펀칭기2', '사무용품', 500, 320, datetime.date(2020, 9, 11)))

# %%
data
# Out:
# (('0001', '티셔츠', '의류', 1000, 500, datetime.date(2020, 9, 20)),
#  ('0002', '펀칭기', '사무용품', 500, 320, datetime.date(2020, 9, 11)),
#  ('0003', '펀칭기2', '사무용품', 500, 320, datetime.date(2020, 9, 11)))

# %%
type(data)
# Out:
# tuple

# %%
query = """
    select * from goods;
"""

mycursor.execute(query)
data = mycursor.fetchone()
con.close()

display(data)
# Out:
# ('0001', '티셔츠', '의류', 1000, 500, datetime.date(2020, 9, 20))

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/shop')
query = '''select * from goods'''
goods = pd.read_sql(query, con=engine)
engine.dispose()

goods.head(10)
# Out:
#   goods_id goods_name goods_classify  sell_price  buy_price register_date
# 0     0001        티셔츠             의류        1000        500    2020-09-20
# 1     0002        펀칭기           사무용품         500        320    2020-09-11
# 2     0003       펀칭기2           사무용품         500        320    2020-09-11
# 3     0009      스테이플러           사무용품        2000       1500    2020-12-30

# %%
import seaborn as sns

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/shop')

iris.to_sql(name='iris', con = engine, index=False, if_exists='replace')
# Out:
# 150

# %%
engine.dispose()

# %%
# !pip install sqlalchemy_utils
# Out:
# Collecting sqlalchemy_utils
#   Downloading SQLAlchemy_Utils-0.41.1-py3-none-any.whl (92 kB)
#      ---------------------------------------- 92.6/92.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy>=1.3 in c:\users\chanj\anaconda3\lib\site-packages (from sqlalchemy_utils) (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\chanj\anaconda3\lib\site-packages (from SQLAlchemy>=1.3->sqlalchemy_utils) (2.0.1)
# Installing collected packages: sqlalchemy_utils
# Successfully installed sqlalchemy_utils-0.41.1

# %%
from sqlalchemy_utils import create_database

# %%
create_database('mysql+pymysql://root:life2023@127.0.0.1:3306/exam')

# %%
price = pd.DataFrame({
    '날짜': ['2021-01-02', '2021-01-03'],
    '티커': ['000001', '000001'],
    '종가': [1340, 1315],
    '거래량': [1000, 2000]
})

# %%
price.head()
# Out:
#            날짜      티커    종가   거래량
# 0  2021-01-02  000001  1340  1000
# 1  2021-01-03  000001  1315  2000

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/exam')
price.to_sql('price', con=engine, if_exists='append', index=False)
data_sql = pd.read_sql('price', con=engine)
engine.dispose()

# %%
new = pd.DataFrame({
    '날짜': ['2021-01-04'],
    '티커': ['000001'],
    '종가': [1320],
    '거래량': [5000]
})

# %%
new.head()
# Out:
#            날짜      티커    종가   거래량
# 0  2021-01-04  000001  1320  5000

# %%
price2 = pd.concat([price, new])

# %%
price2.head()
# Out:
#            날짜      티커    종가   거래량
# 0  2021-01-02  000001  1340  1000
# 1  2021-01-03  000001  1315  2000
# 0  2021-01-04  000001  1320  5000

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/exam')
price2.to_sql('price', con=engine, if_exists='append', index=False)
data_sql = pd.read_sql('price', con=engine)
engine.dispose()

# %%
price = pd.DataFrame({
    '날짜': ['2021-01-04', '2021-01-04'],
    '티커': ['000001', '000002'],
    '종가': [1320, 1315],
    '거래량': [2100, 1500]
})

args = price.values.tolist()
args
# Out:
# [['2021-01-04', '000001', 1320, 2100], ['2021-01-04', '000002', 1315, 1500]]

# %%
con = pymysql.connect(
    user='root',
    passwd='life2023',
    host='127.0.0.1',
    db='exam',
    charset='utf8'
)

query = """
    insert into price2 values (%s,%s,%s,%s) as new
    on duplicate key update
    종가 = new.종가, 거래량 = new.거래량;
"""

mycursor = con.cursor()

mycursor.executemany(query, args)
con.commit()
con.close()

# %%
con = pymysql.connect(
    user='root',
    passwd='life2023',
    host='127.0.0.1',
    db='life2023',
    charset='utf8'
)

query = """
    drop database life2023;
    
"""

mycursor = con.cursor()

mycursor.execute(query)
con.commit()
con.close()

# %% [markdown]
# # 여기서부터는 실제 코드

# %%
# !pip install pymysql sqlalchemy_utils

# %%
import pandas as pd
import numpy as np

from scipy.stats.mstats import winsorize

import time
from datetime import datetime
import pandas_market_calendars as mcal

from joblib import Parallel, delayed
from tqdm import tqdm

import pymysql
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database

# %%
# create_database('mysql+pymysql://root:life2023@127.0.0.1:3306/Life2023')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'life2023'; database exists")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 create_database('mysql+pymysql://root:life2023@127.0.0.1:3306/Life2023')
#
# File ~\anaconda3\lib\site-packages\sqlalchemy_utils\functions\database.py:582, in create_database(url, encoding, template)
#     577     with engine.begin() as conn:
#     578         text = "CREATE DATABASE {} CHARACTER SET = '{}'".format(
#     579             quote(conn, database),
#     580             encoding
#     581         )
# --> 582         conn.execute(sa.text(text))
#     584 elif dialect_name == 'sqlite' and database != ':memory:':
#     585     if database:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1007, "Can't create database 'life2023'; database exists")
# [SQL: CREATE DATABASE `Life2023` CHARACTER SET = 'utf8']
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
path = '/Users/chanj/OneDrive/바탕 화면/Life/datasets-total-ver23060812'

# %%
kosdaq_members = pd.read_csv(f'/Users/chanj/OneDrive/바탕 화면/Life/KOSDAQ_members.csv')

# %%
ksq_mem_list = list(kosdaq_members.ticker_bloomberg)

# %%
def to_db(ticker):
    table = pd.read_csv(f'/Users/chanj/OneDrive/바탕 화면/Life/datasets-KOSDAQ/dataset-KOSDAQ-{ticker}.csv')
    preprocess = preprocessing(table, mode='KOSPI200')
    return preprocess.df

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/life2023')

with Parallel(n_jobs = 12) as parallel:
    results = parallel(delayed(to_db)(ticker) for ticker in tqdm(ksq_mem_list))
    
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with Parallel(n_jobs = 12) as parallel:
#       2     results = parallel(delayed(to_db)(ticker) for ticker in tqdm(ksq_mem_list))
#       4 engine.dispose()
#
# NameError: name 'Parallel' is not defined

# %%
with Parallel(n_jobs = 12) as parallel:
    results = parallel(delayed(to_db)(ticker) for ticker in tqdm(ksq_mem_list))
    
for name, result in tqdm(zip(ksq_mem_list, results)):
    result.to_csv(f'/Users/chanj/OneDrive/바탕 화면/Life/datasets-KOSDAQ/dataset-KOSDAQ-{name}.csv')
# Out:
#   0%|                                                                                         | 0/1623 [00:00<?, ?it/s]
#   1%|█▏                                                                              | 24/1623 [00:03<04:21,  6.11it/s]
#   2%|█▊                                                                              | 36/1623 [00:04<02:57,  8.94it/s]
#   3%|██▎                                                                             | 48/1623 [00:04<02:12, 11.92it/s]
#   4%|██▉                                                                             | 60/1623 [00:05<01:44, 15.00it/s]
#   4%|███▌                                                                            | 72/1623 [00:05<01:26, 17.92it/s]
#   5%|████▏                                                                           | 84/1623 [00:06<01:15, 20.44it/s]
#   6%|████▋                                                                           | 96/1623 [00:06<01:07, 22.71it/s]
#   7%|█████▎                                                                         | 108/1623 [00:06<01:02, 24.37it/s]
#   7%|█████▊                                                                         | 120/1623 [00:07<00:58, 25.82it/s]
#   8%|██████▍                                                                        | 132/1623 [00:07<00:55, 27.02it/s]
#   9%|███████                                                                        | 144/1623 [00:08<00:54, 27.27it/s]
#  10%|███████▌                                                                       | 156/1623 [00:08<00:52, 28.00it/s]
#  10%|████████▏                                                                      | 168/1623 [00:08<00:52, 27.63it/s]
#  11%|████████▊                                                                      | 180/1623 [00:09<00:51, 27.90it/s]
#  12%|█████████▎                                                                     | 192/1623 [00:09<00:50, 28.28it/s]
#  13%|█████████▉                                                                     | 204/1623 [00:10<00:49, 28.65it/s]
#  13%|██████████▌                                                                    | 216/1623 [00:10<00:48, 28.90it/s]
#  14%|███████████                                                                    | 228/1623 [00:11<00:48, 28.84it/s]
#  15%|███████████▋                                                                   | 240/1623 [00:11<00:47, 28.92it/s]
#  16%|████████████▎                                                                  | 252/1623 [00:11<00:47, 28.99it/s]
#  16%|████████████▊                                                                  | 264/1623 [00:12<00:46, 29.21it/s]
#  17%|█████████████▍                                                                 | 276/1623 [00:12<00:46, 29.17it/s]
#  18%|██████████████                                                                 | 288/1623 [00:13<00:47, 28.25it/s]
#  18%|██████████████▌                                                                | 300/1623 [00:13<00:46, 28.46it/s]
#  19%|███████████████▏                                                               | 312/1623 [00:13<00:45, 28.68it/s]
#  20%|███████████████▊                                                               | 324/1623 [00:14<00:45, 28.71it/s]
#  21%|████████████████▎                                                              | 336/1623 [00:14<00:45, 28.50it/s]
/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1623/1623 [01:02<00:00, 25.99it/s]
#
# 0it [00:00, ?it/s]
# 6it [00:00, 54.53it/s]
# 12it [00:00, 57.26it/s]
# 19it [00:00, 62.15it/s]
# 26it [00:00, 60.84it/s]
# 33it [00:00, 63.23it/s]
# 40it [00:00, 63.69it/s]
# 47it [00:00, 63.04it/s]
# 54it [00:00, 62.06it/s]
# 61it [00:00, 61.21it/s]
# 68it [00:01, 61.02it/s]
# 75it [00:01, 58.51it/s]
# 81it [00:01, 58.52it/s]
# 87it [00:01, 58.28it/s]
# 94it [00:01, 59.87it/s]
# 101it [00:01, 61.07it/s]
# 108it [00:01, 62.86it/s]
# 116it [00:01, 65.18it/s]
# 123it [00:01, 63.56it/s]
# 130it [00:02, 61.84it/s]
# 137it [00:02, 61.53it/s]
# 144it [00:02, 59.31it/s]
# 151it [00:02, 60.93it/s]
# 158it [00:02, 63.14it/s]
# 165it [00:02, 60.69it/s]
# 172it [00:02, 62.87it/s]
# 180it [00:02, 65.34it/s]
# 187it [00:03, 62.83it/s]
# 194it [00:03, 61.62it/s]
# 201it [00:03, 61.06it/s]
# 208it [00:03, 59.50it/s]
# 215it [00:03, 61.96it/s]
# 222it [00:03, 62.79it/s]
# 229it [00:03, 63.02it/s]
# 236it [00:03, 64.49it/s]
# 243it [00:03, 65.72it/s]
# 250it [00:04, 63.60it/s]
# 257it [00:04, 62.34it/s]
# 264it [00:04, 63.38it/s]
# 271it [00:04, 63.89it/s]
# 278it [00:04, 64.03it/s]
# 285it [00:04, 62.91it/s]
# 292it [00:04, 63.46it/s]
# 299it [00:04, 62.90it/s]
# 306it [00:04, 64.30it/s]
# 313it [00:05, 62.91it/s]
# 320it [00:05, 64.42it/s]
# 327it [00:05, 63.13it/s]
# 334it [00:05, 63.36it/s]
# 341it [00:05, 58.86it/s]
# 347it [00:05, 58.57it/s]
# 353it [00:05, 58.64it/s]
# 359it [00:05, 57.73it/s]
# 365it [00:05, 57.72it/s]
# 372it [00:06, 59.71it/s]
# 379it [00:06, 61.55it/s]
# 386it [00:06, 60.64it/s]
# 394it [00:06, 64.31it/s]
# 401it [00:06, 62.42it/s]
# 408it [00:06, 60.85it/s]
# 415it [00:06, 61.90it/s]
# 422it [00:06, 62.67it/s]
# 429it [00:06, 62.58it/s]
# 436it [00:07, 61.97it/s]
# 443it [00:07, 59.53it/s]
# 449it [00:07, 58.77it/s]
# 456it [00:07, 60.83it/s]
# 463it [00:07, 58.93it/s]
# 469it [00:07, 58.65it/s]
# 476it [00:07, 59.87it/s]
# 483it [00:07, 61.69it/s]
# 490it [00:07, 56.11it/s]
# 496it [00:08, 53.91it/s]
# 502it [00:08, 55.00it/s]
# 509it [00:08, 58.43it/s]
# 516it [00:08, 61.02it/s]
# 524it [00:08, 64.12it/s]
# 531it [00:08, 64.03it/s]
# 538it [00:08, 64.88it/s]
# 545it [00:08, 65.39it/s]
# 552it [00:08, 63.17it/s]
# 559it [00:09, 64.07it/s]
# 566it [00:09, 65.65it/s]
# 573it [00:09, 65.08it/s]
# 580it [00:09, 62.72it/s]
# 587it [00:09, 57.82it/s]
# 593it [00:09, 58.09it/s]
# 600it [00:09, 60.76it/s]
# 608it [00:09, 64.44it/s]
# 615it [00:09, 63.94it/s]
# 622it [00:10, 62.89it/s]
# 629it [00:10, 62.62it/s]
# 636it [00:10, 62.88it/s]
# 643it [00:10, 62.11it/s]
# 650it [00:10, 64.17it/s]
# 657it [00:10, 65.63it/s]
# 664it [00:10, 64.42it/s]
# 671it [00:10, 64.34it/s]
# 678it [00:10, 65.00it/s]
# 686it [00:11, 67.60it/s]
# 693it [00:11, 67.13it/s]
# 700it [00:11, 65.88it/s]
# 707it [00:11, 65.53it/s]
# 714it [00:11, 63.54it/s]
# 721it [00:11, 62.23it/s]
# 728it [00:11, 61.24it/s]
# 735it [00:11, 57.89it/s]
# 742it [00:12, 58.96it/s]
# 748it [00:12, 59.17it/s]
# 754it [00:12, 59.10it/s]
# 761it [00:12, 60.47it/s]
# 768it [00:12, 62.41it/s]
# 775it [00:12, 62.86it/s]
# 784it [00:12, 68.86it/s]
# 791it [00:12, 65.27it/s]
# 798it [00:12, 65.72it/s]
# 806it [00:12, 69.27it/s]
# 814it [00:13, 70.32it/s]
# 822it [00:13, 72.37it/s]
# 830it [00:13, 68.93it/s]
# 839it [00:13, 74.70it/s]
# 847it [00:13, 74.17it/s]
# 855it [00:13, 66.37it/s]
# 862it [00:13, 66.49it/s]
# 869it [00:13, 64.20it/s]
# 876it [00:14, 63.34it/s]
# 883it [00:14, 59.85it/s]
# 890it [00:14, 60.06it/s]
# 898it [00:14, 64.72it/s]
# 905it [00:14, 63.60it/s]
# 912it [00:14, 62.21it/s]
# 920it [00:14, 64.65it/s]
# 928it [00:14, 67.44it/s]
# 935it [00:14, 67.28it/s]
# 942it [00:15, 66.41it/s]
# 950it [00:15, 68.19it/s]
# 959it [00:15, 72.82it/s]
# 967it [00:15, 69.26it/s]
# 974it [00:15, 67.53it/s]
# 984it [00:15, 74.18it/s]
# 992it [00:15, 74.05it/s]
# 1001it [00:15, 75.89it/s]
# 1009it [00:15, 73.17it/s]
# 1017it [00:16, 67.93it/s]
# 1025it [00:16, 69.27it/s]
# 1032it [00:16, 68.56it/s]
# 1041it [00:16, 71.59it/s]
# 1049it [00:16, 69.26it/s]
# 1056it [00:16, 69.09it/s]
# 1063it [00:16, 66.40it/s]
# 1072it [00:16, 70.41it/s]
# 1080it [00:16, 65.67it/s]
# 1087it [00:17, 63.83it/s]
# 1094it [00:17, 65.06it/s]
# 1101it [00:17, 64.62it/s]
# 1108it [00:17, 63.04it/s]
# 1117it [00:17, 67.34it/s]
# 1124it [00:17, 66.08it/s]
# 1132it [00:17, 67.95it/s]
# 1139it [00:17, 67.14it/s]
# 1147it [00:18, 68.44it/s]
# 1156it [00:18, 73.70it/s]
# 1164it [00:18, 74.19it/s]
# 1172it [00:18, 71.89it/s]
# 1180it [00:18, 73.40it/s]
# 1189it [00:18, 75.42it/s]
# 1198it [00:18, 77.21it/s]
# 1208it [00:18, 81.13it/s]
# 1219it [00:18, 87.84it/s]
# 1230it [00:18, 92.80it/s]
# 1241it [00:19, 96.36it/s]
# 1251it [00:19, 94.42it/s]
# 1262it [00:19, 96.42it/s]
# 1273it [00:19, 99.84it/s]
# 1284it [00:19, 100.52it/s]
# 1300it [00:19, 115.65it/s]
# 1313it [00:19, 117.23it/s]
# 1330it [00:19, 132.27it/s]
# 1345it [00:19, 136.81it/s]
# 1359it [00:20, 131.82it/s]
# 1375it [00:20, 138.67it/s]
# 1389it [00:20, 138.50it/s]
# 1405it [00:20, 141.70it/s]
# 1420it [00:20, 143.86it/s]
# 1437it [00:20, 151.10it/s]
# 1459it [00:20, 170.58it/s]
# 1485it [00:20, 196.29it/s]
# 1509it [00:20, 208.89it/s]
# 1537it [00:20, 228.33it/s]
# 1623it [00:21, 76.79it/s]

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/life2023')
for ticker, df in tqdm(zip(ksq_mem_list, results)):
    df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
engine.dispose()
# Out:
# 0it [00:00, ?it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '000250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1it [00:00,  3.54it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '000440_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 2it [00:00,  4.47it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '001000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 3it [00:00,  4.72it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '001540_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 4it [00:00,  4.67it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '001810_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 5it [00:01,  4.69it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '001840_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 6it [00:01,  4.83it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '002230_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 7it [00:01,  5.10it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '002290_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 8it [00:01,  5.24it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '002680_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 9it [00:01,  5.29it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '002800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 10it [00:01,  5.71it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '003100_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 11it [00:02,  5.77it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '003310_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 12it [00:02,  5.76it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '003380_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 13it [00:02,  6.04it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '003800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 14it [00:02,  5.94it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '004590_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 15it [00:02,  5.84it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '004650_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 16it [00:03,  5.65it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '004780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 17it [00:03,  5.64it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005160_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 18it [00:03,  4.74it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005290_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 19it [00:03,  4.96it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 20it [00:03,  5.11it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005710_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 21it [00:04,  5.18it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005860_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 22it [00:04,  5.11it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '005990_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 23it [00:04,  5.26it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 24it [00:04,  5.39it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006140_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 25it [00:04,  5.39it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006580_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 26it [00:04,  5.53it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 27it [00:05,  6.00it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006730_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 28it [00:05,  5.93it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006910_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 29it [00:05,  5.85it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '006920_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 30it [00:05,  5.59it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007330_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 31it [00:05,  5.52it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007370_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 32it [00:05,  5.59it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007390_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 33it [00:06,  5.46it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007530_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 34it [00:06,  5.41it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007680_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 35it [00:06,  5.84it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007720_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 36it [00:06,  5.66it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007770_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 37it [00:06,  5.64it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '007820_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 38it [00:07,  4.94it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '008290_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 39it [00:07,  5.10it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '008370_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 40it [00:07,  5.31it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '008470_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 41it [00:07,  5.40it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '008830_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 42it [00:07,  5.33it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '009300_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 43it [00:08,  5.36it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '009520_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 44it [00:08,  5.02it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '009620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 45it [00:08,  5.17it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '009730_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 46it [00:08,  5.36it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '009780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 47it [00:08,  5.52it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '010170_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 48it [00:08,  5.52it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '010240_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 49it [00:09,  5.49it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '010280_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 50it [00:09,  5.46it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '010470_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 51it [00:09,  5.48it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '011040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 52it [00:09,  5.40it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '011080_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 53it [00:09,  5.39it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '011320_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 54it [00:10,  5.50it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '011370_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 55it [00:10,  5.45it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '011560_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 56it [00:10,  5.56it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '012340_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 57it [00:10,  5.58it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '012620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 58it [00:10,  4.87it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '012700_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 59it [00:11,  5.17it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '012790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 60it [00:11,  5.22it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '012860_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 61it [00:11,  5.26it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013030_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 62it [00:11,  5.41it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 63it [00:11,  5.59it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013310_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 64it [00:11,  5.83it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013720_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 65it [00:12,  5.80it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013810_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 66it [00:12,  5.70it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '013990_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 67it [00:12,  5.67it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014100_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 68it [00:12,  5.65it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014190_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 69it [00:12,  5.44it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014200_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 70it [00:12,  5.44it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014470_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 71it [00:13,  5.48it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014570_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 72it [00:13,  5.47it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 73it [00:13,  5.63it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014940_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 74it [00:13,  5.62it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '014970_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 75it [00:13,  5.64it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '015710_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 76it [00:14,  5.56it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '015750_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 77it [00:14,  5.60it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016100_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 78it [00:14,  4.88it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 79it [00:14,  5.16it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016600_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 80it [00:14,  5.28it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 81it [00:15,  5.32it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 82it [00:15,  5.94it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '016920_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 83it [00:15,  5.89it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 84it [00:15,  5.74it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 85it [00:15,  5.69it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017480_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 86it [00:15,  5.71it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017510_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 87it [00:16,  5.72it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017650_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 88it [00:16,  5.68it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '017890_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 89it [00:16,  5.55it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 90it [00:16,  5.31it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 91it [00:16,  5.32it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018290_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 92it [00:16,  5.45it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018310_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 93it [00:17,  5.43it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 94it [00:17,  5.37it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018680_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 95it [00:17,  5.55it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '018700_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 96it [00:17,  5.61it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019010_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 97it [00:17,  5.67it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019210_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 98it [00:18,  5.61it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019540_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 99it [00:18,  4.74it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019550_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 100it [00:18,  4.86it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019570_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 101it [00:18,  4.91it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019590_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 102it [00:18,  4.96it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019660_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 103it [00:19,  5.16it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019770_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 104it [00:19,  5.34it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '019990_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 105it [00:19,  5.47it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '020180_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 106it [00:19,  5.55it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '020400_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 107it [00:19,  5.60it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '020710_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 108it [00:19,  5.46it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '021040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 109it [00:20,  5.50it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '021080_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 110it [00:20,  5.42it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '021320_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 111it [00:20,  5.51it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '021650_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 112it [00:20,  5.56it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '021880_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 113it [00:20,  5.64it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '022100_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 114it [00:21,  5.60it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '022220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 115it [00:21,  5.65it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023160_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 116it [00:21,  5.62it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023410_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 117it [00:21,  4.92it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023440_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 118it [00:21,  5.17it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023460_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 119it [00:22,  5.25it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023600_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 120it [00:22,  5.25it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023760_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 121it [00:22,  5.40it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023770_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 122it [00:22,  5.52it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 123it [00:22,  5.42it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023900_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 124it [00:22,  5.47it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '023910_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 125it [00:23,  5.52it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '024060_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 126it [00:23,  5.34it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '024120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 127it [00:23,  5.39it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '024740_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 128it [00:23,  5.37it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '024800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# ...
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '425290_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1580it [04:27, 12.20it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '425420_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '426550_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1582it [04:27,  9.93it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '427950_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '430220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1584it [04:28, 10.51it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '430230_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '430460_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1586it [04:28, 11.01it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '430700_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '433530_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1588it [04:28, 11.08it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '434480_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '435380_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1590it [04:28, 11.53it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '435620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '435870_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1592it [04:28, 11.79it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '436530_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '436610_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1594it [04:28, 11.65it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '437780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '438220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1596it [04:29, 11.82it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '438580_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '439090_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 1598it [04:29,  9.80it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '439250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '439410_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1600it [04:29, 10.40it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '439730_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '440200_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1602it [04:29, 10.86it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '440790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '440820_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1604it [04:29, 11.10it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '441270_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '442130_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1606it [04:30, 11.42it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '442310_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '442770_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1608it [04:30, 11.67it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '442900_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '445360_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1610it [04:30, 12.05it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '445970_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '446150_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1612it [04:30, 12.27it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '446190_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '446750_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1614it [04:30, 12.69it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '446840_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '448370_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1616it [04:30, 10.23it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '448740_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '448760_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1618it [04:31, 11.02it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '448830_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '449020_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1620it [04:31, 11.77it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '450050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '450410_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
#
# 1622it [04:31, 12.23it/s]C:\Users\chanj\AppData\Local\Temp\ipykernel_11572\738995370.py:3: UserWarning: The provided table name '451700_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# 1623it [04:31,  5.98it/s]

# %%
kospi_members = pd.read_csv(f'{path}/dataset-members/dataset-KOSPI200-members.csv')
ks_mem_list = []
for ks_mem in kospi_members.value.tolist():
    ks_mem = ks_mem.replace('/', '_')
    ks_mem_list.append(ks_mem)

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/life2023')
for ticker in ks_mem_list:
    table = pd.read_csv(f'{path}/datasets-KOSPI200/dataset-KOSPI200-{ticker}.csv')
    preprocess = preprocessing(table, mode='KOSPI200')
    preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
engine.dispose()
# Out:
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000080_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000100_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000150_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000210_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000240_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000270_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000660_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000720_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000810_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000880_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '000990_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001230_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001440_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001450_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001680_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001740_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '001800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '002380_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '002790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003090_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003230_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003240_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003410_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003490_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003550_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '003850_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004020_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004170_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004370_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004490_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '004990_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005300_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005380_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005490_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005830_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005850_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005930_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '005940_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006260_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006280_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006360_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006400_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006650_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '006800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '007070_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '007310_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '008770_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '008930_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009150_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009240_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009420_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009540_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009830_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '009900_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010060_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010120_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010130_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010140_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '010950_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011070_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011170_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011200_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011210_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '011790_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '012330_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '012450_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '012750_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '013890_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '014680_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '014820_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '015760_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '016360_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '016380_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '017670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '017800_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '018260_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '018880_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '019170_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '020000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '020150_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '020560_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '021240_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '023530_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '024110_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '026960_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '028050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '028260_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '028670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '029780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '030000_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '030200_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '031430_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '032350_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '032640_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '032830_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '033780_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '034020_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '034220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '034730_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '035250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '035420_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '035720_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '036460_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '036570_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '039130_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '039490_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '042660_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '042670_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '047040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '047050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '047810_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '051600_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '051900_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '051910_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '052690_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '055550_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '057050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '064350_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '066570_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '068270_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '069260_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '069620_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# ...
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '138040_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '138930_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '139130_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '139480_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '161390_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '161890_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '175330_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '178920_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '180640_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '185750_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '192080_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '192820_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '204320_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '207940_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '241560_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '241590_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '251270_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '259960_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '267250_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '271560_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '271940_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '272210_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '280360_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '282330_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '284740_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '285130_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '294870_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '298020_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '298050_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '300720_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '302440_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '316140_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '323410_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '326030_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '329180_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '336260_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '352820_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '361610_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '373220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '375500_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '377300_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '381970_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '383220_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\3449739730.py:5: UserWarning: The provided table name '402340_KS' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='append', index=True)

# %%
russell_members = pd.read_csv(f'{path}/dataset-members/dataset-RUSSELL3000-members.csv')
rs_mem_list = []
for rs_mem in russell_members.value.tolist():
    rs_mem = rs_mem.replace('/', '_')
    rs_mem_list.append(rs_mem)

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/life2023')
for ticker in rs_mem_list:
    table = pd.read_csv(f'{path}/datasets-RUSSELL3000/dataset-RUSSELL3000-{ticker}.csv')
    preprocess = preprocessing(table, mode='RUSSELL3000')
    preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
engine.dispose()
# Out:
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'A_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AA_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AAL_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AAP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AAPL_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ABBV_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ABC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ABNB_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ABT_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ACGL_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ACHC_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ACI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ACM_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ACN_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADBE_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADI_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADM_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADP_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADSK_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ADT_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AEE_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AEP_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AES_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AFG_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AFL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AFRM_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AGCO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AGL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AGNC_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AGO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AGR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AIG_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AIRC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AIZ_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AJG_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AKAM_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALB_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALGM_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALGN_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALLE_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALLY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALNY_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ALSN_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AM_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMAT_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMBP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMCR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMD_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AME_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMED_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMG_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMGN_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMH_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMT_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AMZN_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AN_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ANET_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ANSS_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AON_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AOS_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APA_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APD_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APH_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APP_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'APTV_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ARE_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ARES_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ARMK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ARW_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ASH_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ATO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ATR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ATUS_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ATVI_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AVB_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AVGO_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AVT_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AVTR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AVY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AWI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AWK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AXON_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AXP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AXS_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AXTA_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AYI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AYX_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AZEK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AZO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AZPN_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'AZTA_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BA_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BAC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BAH_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BALL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BAX_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BBWI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BBY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BDX_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BEN_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BEPC_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BERY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BF_A_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BF_B_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BFAM_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BG_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BHF_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BIIB_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BILL_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BIO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BJ_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BKI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BKNG_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BKR_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BLD_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BLDR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BLK_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BMRN_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BMY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BOH_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BOKF_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BPOP_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BRK_B_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'BRKR_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# ...
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WOR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WOW_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WRBY_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WRLD_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WSBC_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WSBF_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WSFS_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WSR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WT_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WTBA_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WTI_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WTS_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WTTR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WULF_UR' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WW_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'WWW_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XERS_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XHR_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XMTR_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XNCR_UQ' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XOS_UQ' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XPEL_UR' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XPER_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XPOF_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XPRO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XRX_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'XXII_UR' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'YELP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'YEXT_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'YMAB_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'YORW_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'YOU_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZD_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZETA_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZEUS_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZEV_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZGN_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZIMV_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZIP_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZNTL_UQ' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZUMZ_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZUO_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZWS_UN' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)
# C:\Users\chanj\AppData\Local\Temp\ipykernel_22360\2323174684.py:5: UserWarning: The provided table name 'ZYXI_UW' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   preprocess.df.to_sql(ticker.replace(' ','_'), con=engine, if_exists='replace', index=True)

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/life2023')
query = """select * from 000080_KS"""
df = pd.read_sql(query, con=engine)
engine.dispose()
df
# Out:
#             date  PX_OPEN   PX_LOW  PX_HIGH  PX_LAST    VOLUME  MOV_AVG_5D  \
# 0     2015-01-02  23100.0  22350.0  23100.0  22600.0  184419.0     23750.0
# 1     2015-01-05  22600.0  22400.0  23150.0  23050.0  170602.0     23430.0
# 2     2015-01-06  22750.0  22550.0  23100.0  22650.0  142141.0     22980.0
# 3     2015-01-07  22650.0  22350.0  23050.0  22700.0  159007.0     22850.0
# 4     2015-01-08  22600.0  22600.0  23100.0  22850.0  126066.0     22770.0
# ...          ...      ...      ...      ...      ...       ...         ...
# 2068  2023-05-26  23700.0  23350.0  23850.0  23450.0  267538.0     23740.0
# 2069  2023-05-30  23700.0  22900.0  23750.0  23000.0  412668.0     23560.0
# 2070  2023-05-31  23050.0  22900.0  23400.0  22900.0  329872.0     23380.0
# 2071  2023-06-01  22900.0  22500.0  22950.0  22500.0  319230.0     23110.0
# 2072  2023-06-02  22550.0  22450.0  22750.0  22650.0  215435.0     22900.0
#
#       CHG_PCT_1D
# 0        -2.7957
# 1         1.9912
# 2        -1.7354
# 3         0.2208
# 4         0.6608
# ...          ...
# 2068     -1.0549
# 2069     -1.9190
# 2070     -0.4348
# 2071     -1.7467
# 2072      0.6667
#
# [2073 rows x 8 columns]

# %%
def non_shared_holidays(df, market, start_date, end_date):
    start_date_str = start_date.strftime('%Y-%m-%d')
    end_date_str = end_date.strftime('%Y-%m-%d')
    market_trading_day = market.schedule(start_date=start_date, end_date=end_date)
    df_trading_day = df.index
    non_shared_holidays_list = sorted(set(market_trading_day.index) - set(df_trading_day))
    return non_shared_holidays_list

krx = mcal.get_calendar('XKRX')
nyse = mcal.get_calendar('NYSE')
# Out:
# C:\Users\chanj\anaconda3\lib\site-packages\pandas_market_calendars\market_calendar.py:144: UserWarning: ['break_start', 'break_end'] are discontinued, the dictionary `.discontinued_market_times` has the dates on which these were discontinued. The times as of those dates are incorrect, use .remove_time(market_time) to ignore a market_time.
#   warnings.warn(f"{list(discontinued.keys())} are discontinued, the dictionary"

# %%
def fill_na(df):
    columns_ffill = ['PX_OPEN', 'PX_LOW', 'PX_HIGH', 'PX_LAST', 'VOLUME', 'MOV_AVG_5D']
    columns_zero_fill = ['CHG_PCT_1D', 'LOG_CHG_PCT_1D']
    
    for column in columns_ffill:
        df[column] = df[column].fillna(method='ffill')
    
    for column in columns_zero_fill:
        df[column] = df[column].fillna(0)
        
    return df

# %%
class preprocessing:
    def __init__(self,df, mode):
        self.df = df
        self.mode = mode
        self.index_to_datetime()
        self.make_log_chg_pct_1d()
        self.cut_with_valid_date()
        self.fill_non_shared_holidays()
        self.winsorizing()
        
    def index_to_datetime(self):
        self.df['date'] = pd.to_datetime(self.df['date'])
        self.df.set_index('date', inplace=True)
        
    def make_log_chg_pct_1d(self):
        self.df['LOG_CHG_PCT_1D'] = np.log(self.df['CHG_PCT_1D']/100 + 1)
    
    def cut_with_valid_date(self):
        first_valid_date = np.where(~np.isnan(self.df.to_numpy()).any(axis=1))[0][0]
        self.df = self.df.iloc[first_valid_date:]
        
    def fill_non_shared_holidays(self):
        if self.mode is 'KOSPI200':
            index_to_fill = non_shared_holidays(self.df, nyse, self.df.index[0], self.df.index[-1]) 
        elif self.mode is 'RUSSELL3000':
            index_to_fill = non_shared_holidays(self.df, krx, self.df.index[0], self.df.index[-1])
            
        self.df = self.df.reindex(self.df.index.union(index_to_fill))
    
        self.df = fill_na(self.df)
        
    def winsorizing(self):
        self.df['LOG_CHG_PCT_1D_win'] = winsorize(self.df['LOG_CHG_PCT_1D'], limits=(0.05, 0.05))
# Out:
# <>:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\chanj\AppData\Local\Temp\ipykernel_13212\2677273830.py:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.mode is 'KOSPI200':
# C:\Users\chanj\AppData\Local\Temp\ipykernel_13212\2677273830.py:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.mode is 'RUSSELL3000':
