# %%
import pandas as pd

import datetime
import pandas_market_calendars as mcal

import itertools
from joblib import Parallel, delayed

# import web_Bloomberg_to_MySQL_bulk as wBtMb|

###

import numpy as np
# from itertools import accumulate

# import matplotlib.pyplot as plt

# from sklearn.metrics import mean_squared_error as mse
from scipy.stats import pearsonr
# from scipy.stats.mstats import winsorize
# from tslearn.metrics import dtw

# from scipy.stats import rankdata

# from tqdm.notebook import tqdm
# 

# import time
# from datetime import datetime
# import pandas_market_calendars as mcal

# import pymysql
from sqlalchemy import create_engine
# from sqlalchemy_utils import create_database

# import warnings

# # Ignore all warnings
# warnings.filterwarnings("ignore")

# %%
daily_end_date = datetime.date.today().strftime('%Y%m%d')

krx = mcal.get_calendar('XKRX')
nyse = mcal.get_calendar('NYSE')

krx_trading_day = krx.schedule(start_date=wBtMb.bulk_start_date, end_date=daily_end_date).index.tolist()
nyse_trading_day = nyse.schedule(start_date=wBtMb.bulk_start_date, end_date=daily_end_date).index.tolist()
        
all_trading_days_list = sorted(set(krx_trading_day + nyse_trading_day))

all_trading_days_dict = {}

for i, day in enumerate(all_trading_days_list):
    all_trading_days_dict[i+1] = day
# Out:
# C:\Users\chanj\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\pandas_market_calendars\market_calendar.py:144: UserWarning: ['break_start', 'break_end'] are discontinued, the dictionary `.discontinued_market_times` has the dates on which these were discontinued. The times as of those dates are incorrect, use .remove_time(market_time) to ignore a market_time.
#   warnings.warn(f"{list(discontinued.keys())} are discontinued, the dictionary"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 krx = mcal.get_calendar('XKRX')
#       4 nyse = mcal.get_calendar('NYSE')
# ----> 6 krx_trading_day = krx.schedule(start_date=wBtMb.bulk_start_date, end_date=daily_end_date).index.tolist()
#       7 nyse_trading_day = nyse.schedule(start_date=wBtMb.bulk_start_date, end_date=daily_end_date).index.tolist()
#       9 all_trading_days_list = sorted(set(krx_trading_day + nyse_trading_day))
#
# NameError: name 'wBtMb' is not defined

# %%
daily_end_date = datetime.date.today().strftime('%Y%m%d')

krx = mcal.get_calendar('XKRX')
nyse = mcal.get_calendar('NYSE')

krx_trading_day = krx.schedule(start_date='20150101', end_date=daily_end_date).index.tolist()
nyse_trading_day = nyse.schedule(start_date='20150101', end_date=daily_end_date).index.tolist()
        
all_trading_days_list = sorted(set(krx_trading_day + nyse_trading_day))

all_trading_days_dict = {}

for i, day in enumerate(all_trading_days_list):
    all_trading_days_dict[i+1] = day
# Out:
# C:\Users\chanj\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\pandas_market_calendars\market_calendar.py:144: UserWarning: ['break_start', 'break_end'] are discontinued, the dictionary `.discontinued_market_times` has the dates on which these were discontinued. The times as of those dates are incorrect, use .remove_time(market_time) to ignore a market_time.
#   warnings.warn(f"{list(discontinued.keys())} are discontinued, the dictionary"

# %%
def get_shift_corr(ticker1, ticker2, window_size):
    
    engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/datasets')
    
    df1 = pd.read_sql(f'select date_keys, PX_LAST, LOG_CHG_PCT_1D_win from {ticker1}', con=engine, index_col='date_keys')
    df2 = pd.read_sql(f'select date_keys, PX_LAST, LOG_CHG_PCT_1D_win from {ticker2}', con=engine, index_col='date_keys')
    
    engine.dispose()
    
    if df1.index[0] < df2.index[0]:
        start_key = df2.index[0] + window_size - 1
    else:
        start_key = df1.index[0] + window_size - 1
    if df1.index[-1] < df2.index[-1]:
        end_key = df1.index[-1]
    else:
        end_key = df2.index[-1]
        
    if start_key > end_key:
        return None
    
    key_list = list(range(start_key, end_key+1))
    
    result_for_df = []
    
    ticker1_px = np.array(df1.loc[start_key-window_size+1:end_key]['PX_LAST'])
    ticker2_px = np.array(df2.loc[start_key-window_size+1:end_key]['PX_LAST'])
    ticker1_log = np.array(df1.loc[start_key-window_size+1:end_key]['LOG_CHG_PCT_1D_win'])
    ticker2_log = np.array(df2.loc[start_key-window_size+1:end_key]['LOG_CHG_PCT_1D_win'])
    
    global all_trading_days_dict
    
    for i, key in enumerate(key_list):
        j = i + window_size
        
        try:
            corr_px, p_val_px = pearsonr(ticker1_px[i:j], ticker2_px[i:j])
            if p_val_px > 0.05:
                corr_px = np.nan
        except:
            corr_px = np.nan

        try:
            corr_log, p_val_log = pearsonr(ticker1_log[i:j], ticker2_log[i:j])
            if p_val_log > 0.05:
                corr_log = np.nan
        except:
            corr_log = np.nan
            
        date = all_trading_days_dict[key]
        
        result = [date, key, corr_px, corr_log]
        result_for_df.append(result)
    
    result_df = pd.DataFrame(result_for_df, columns=['date', 'date_keys', 'corr_px', 'corr_log_r(win)'])
    result_df = result_df.set_index('date')
    result_df['corr_w_sum'] = 0.2 * result_df['corr_px'] ** 2 + 0.8 * result_df['corr_log_r(win)'] ** 2
    
    engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/results')
    result_df.to_sql(f'{ticker1}_{ticker2}_corr_len{window_size}'.lower(), con=engine, if_exists='replace', index=True)
    engine.dispose()

# %%
members_list_df = pd.read_csv('members_list_by_date.csv', index_col = 0)
members_list = sorted(eval(members_list_df.iloc[-1]['members_list']))
ks_mems_list = []
rs_mems_list = []
for mems in members_list:
    if mems.endswith('KS'):
        ks_mems_list.append(mems)
    else:
        rs_mems_list.append(mems)
ks_pairs_list = list(itertools.combinations(ks_mems_list, 2))
ks_rs_pairs_list = list(itertools.product(ks_mems_list, rs_mems_list))
all_pairs_list = ks_pairs_list + ks_rs_pairs_list

# %%
from tqdm import tqdm

# %%
len(all_pairs_list)
# Out:
# 601700

# %%
with Parallel(n_jobs = 10) as parallel:
    parallel(delayed(get_shift_corr)(pair[0], pair[1], 60) for pair in tqdm(qw))
# Out:
#   1%|▊                                                                           | 670/66149 [00:53<4:08:48,  4.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\parallel.py:1587, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1586     with self._backend.retrieval_context():
# -> 1587         yield from self._retrieve()
#    1589 except GeneratorExit:
#    1590     # The generator has been garbage collected before being fully
#    1591     # consumed. This aborts the remaining tasks if possible and warn
#    1592     # the user if necessary.
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1696 if ((len(self._jobs) == 0) or
#    1697     (self._jobs[0].get_status(
#    1698         timeout=self.timeout) == TASK_PENDING)):
# -> 1699     time.sleep(0.01)
#    1700     continue
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 with Parallel(n_jobs = 10) as parallel:
# ----> 2     parallel(delayed(get_shift_corr)(pair[0], pair[1], 60) for pair in tqdm(qw))
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\parallel.py:1944, in Parallel.__call__(self, iterable)
#    1938 # The first item from the output is blank, but it makes the interpreter
#    1939 # progress until it enters the Try/Except block of the generator and
#    1940 # reach the first `yield` statement. This starts the aynchronous
#    1941 # dispatch of the tasks to the workers.
#    1942 next(output)
# -> 1944 return output if self.return_generator else list(output)
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\parallel.py:1640, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1638 except BaseException:
#    1639     self._exception = True
# -> 1640     self._abort()
#    1641     raise
#    1642 finally:
#    1643     # Store the unconsumed tasks and terminate the workers if necessary
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\parallel.py:1551, in Parallel._abort(self)
#    1546 if (not self._aborted and hasattr(backend, 'abort_everything')):
#    1547     # If the backend is managed externally we need to make sure
#    1548     # to leave it in a working state to allow for future jobs
#    1549     # scheduling.
#    1550     ensure_ready = self._managed_backend
# -> 1551     backend.abort_everything(ensure_ready=ensure_ready)
#    1552 self._aborted = True
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\_parallel_backends.py:632, in LokyBackend.abort_everything(self, ensure_ready)
#     629 def abort_everything(self, ensure_ready=True):
#     630     """Shutdown the workers and restart a new one with the same parameters
#     631     """
# --> 632     self._workers.terminate(kill_workers=True)
#     633     self._workers = None
#     635     if ensure_ready:
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\executor.py:75, in MemmappingExecutor.terminate(self, kill_workers)
#      73 def terminate(self, kill_workers=False):
# ---> 75     self.shutdown(kill_workers=kill_workers)
#      77     # When workers are killed in a brutal manner, they cannot execute the
#      78     # finalizer of their shared memmaps. The refcount of those memmaps may
#      79     # be off by an unknown number, so instead of decref'ing them, we force
#    (...)
#      84     # with allow_non_empty=True but if we can't, it will be clean up later
#      85     # on by the resource_tracker.
#      86     with self._submit_resize_lock:
#
# File ~\OneDrive\바탕 화면\life_web_ui\venv\lib\site-packages\joblib\externals\loky\process_executor.py:1303, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1299 if executor_manager_thread is not None and wait:
#    1300     # This locks avoids concurrent join if the interpreter
#    1301     # is shutting down.
#    1302     with _global_shutdown_lock:
# -> 1303         executor_manager_thread.join()
#    1304         _threads_wakeups.pop(executor_manager_thread, None)
#    1306 # To reduce the risk of opening too many files, remove references to
#    1307 # objects that use file descriptors.
#
# File ~\AppData\Local\Programs\Python\Python38\lib\threading.py:1011, in Thread.join(self, timeout)
#    1008     raise RuntimeError("cannot join current thread")
#    1010 if timeout is None:
# -> 1011     self._wait_for_tstate_lock()
#    1012 else:
#    1013     # the behavior of a negative timeout isn't documented, but
#    1014     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1015     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\Programs\Python\Python38\lib\threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# KeyboardInterrupt:

# %%
all_pairs_list[0]
# Out:
# ('000080_KS', '000100_KS')

# %%
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine('mysql+pymysql://root:life2023@127.0.0.1:3306/results')

# Create an Inspector object
inspector = inspect(engine)

# Get the table names in the database
table_names = inspector.get_table_names()

# %%
tt = [pair[0]+'_'+pair[1]+'_CORR_LEN60' for pair in all_pairs_list]

# %%
table_names = [table.upper() for table in table_names]

# %%
ss = set(tt) - set(table_names)

# %%
kk = sorted(ss)

# %%
kk = [x[:-11] for x in kk]

# %%
kk[-1]
# Out:
# '402340_KS_STHO_UQ'

# %%
qw = [(pair[0:9],pair[10:]) for pair in kk]

# %%
qw
# Out:
# [('000080_KS', 'CR_UN'),
#  ('000080_KS', 'KNF_UN'),
#  ('000080_KS', 'MSGE_UN'),
#  ('000080_KS', 'STHO_UQ'),
#  ('000100_KS', 'CR_UN'),
#  ('000100_KS', 'KNF_UN'),
#  ('000100_KS', 'MSGE_UN'),
#  ('000100_KS', 'STHO_UQ'),
#  ('000120_KS', 'CR_UN'),
#  ('000120_KS', 'KNF_UN'),
#  ('000120_KS', 'MSGE_UN'),
#  ('000120_KS', 'STHO_UQ'),
#  ('000150_KS', 'CR_UN'),
#  ('000150_KS', 'KNF_UN'),
#  ('000150_KS', 'MSGE_UN'),
#  ('000150_KS', 'STHO_UQ'),
#  ('000210_KS', 'CR_UN'),
#  ('000210_KS', 'KNF_UN'),
#  ('000210_KS', 'MSGE_UN'),
#  ('000210_KS', 'STHO_UQ'),
#  ('000240_KS', 'CR_UN'),
#  ('000240_KS', 'KNF_UN'),
#  ('000240_KS', 'MSGE_UN'),
#  ('000240_KS', 'STHO_UQ'),
#  ('000270_KS', 'CR_UN'),
#  ('000270_KS', 'KNF_UN'),
#  ('000270_KS', 'MSGE_UN'),
#  ('000270_KS', 'STHO_UQ'),
#  ('000660_KS', 'CR_UN'),
#  ('000660_KS', 'KNF_UN'),
#  ('000660_KS', 'MSGE_UN'),
#  ('000660_KS', 'STHO_UQ'),
#  ('000670_KS', 'CR_UN'),
#  ('000670_KS', 'KNF_UN'),
#  ('000670_KS', 'MSGE_UN'),
#  ('000670_KS', 'STHO_UQ'),
#  ('000720_KS', 'CR_UN'),
#  ('000720_KS', 'KNF_UN'),
#  ('000720_KS', 'MSGE_UN'),
#  ('000720_KS', 'STHO_UQ'),
#  ('000810_KS', 'CR_UN'),
#  ('000810_KS', 'KNF_UN'),
#  ('000810_KS', 'MSGE_UN'),
#  ('000810_KS', 'STHO_UQ'),
#  ('000880_KS', 'CR_UN'),
#  ('000880_KS', 'KNF_UN'),
#  ('000880_KS', 'MSGE_UN'),
#  ('000880_KS', 'STHO_UQ'),
#  ('000990_KS', 'CR_UN'),
#  ('000990_KS', 'KNF_UN'),
#  ('000990_KS', 'MSGE_UN'),
#  ('000990_KS', 'STHO_UQ'),
#  ('001040_KS', 'CR_UN'),
#  ('001040_KS', 'KNF_UN'),
#  ('001040_KS', 'MSGE_UN'),
#  ('001040_KS', 'STHO_UQ'),
#  ('001120_KS', 'CR_UN'),
#  ('001120_KS', 'KNF_UN'),
#  ('001120_KS', 'MSGE_UN'),
#  ('001120_KS', 'STHO_UQ'),
#  ('001230_KS', 'CR_UN'),
#  ('001230_KS', 'KNF_UN'),
#  ('001230_KS', 'MSGE_UN'),
#  ('001230_KS', 'STHO_UQ'),
#  ('001440_KS', 'CR_UN'),
#  ('001440_KS', 'KNF_UN'),
#  ('001440_KS', 'MSGE_UN'),
#  ('001440_KS', 'STHO_UQ'),
#  ('001450_KS', 'CR_UN'),
#  ('001450_KS', 'KNF_UN'),
#  ('001450_KS', 'MSGE_UN'),
#  ('001450_KS', 'STHO_UQ'),
#  ('001680_KS', 'CR_UN'),
#  ('001680_KS', 'KNF_UN'),
#  ('001680_KS', 'MSGE_UN'),
#  ('001680_KS', 'STHO_UQ'),
#  ('001740_KS', 'CR_UN'),
#  ('001740_KS', 'KNF_UN'),
#  ('001740_KS', 'MSGE_UN'),
#  ('001740_KS', 'STHO_UQ'),
#  ('001800_KS', 'CR_UN'),
#  ('001800_KS', 'KNF_UN'),
#  ('001800_KS', 'MSGE_UN'),
#  ('001800_KS', 'STHO_UQ'),
#  ('002380_KS', 'CR_UN'),
#  ('002380_KS', 'KNF_UN'),
#  ('002380_KS', 'MSGE_UN'),
#  ('002380_KS', 'STHO_UQ'),
#  ('002790_KS', 'CR_UN'),
#  ('002790_KS', 'KNF_UN'),
#  ('002790_KS', 'MSGE_UN'),
#  ('002790_KS', 'STHO_UQ'),
#  ('003090_KS', 'CR_UN'),
#  ('003090_KS', 'KNF_UN'),
#  ('003090_KS', 'MSGE_UN'),
#  ('003090_KS', 'STHO_UQ'),
#  ('003230_KS', 'CR_UN'),
#  ('003230_KS', 'KNF_UN'),
#  ('003230_KS', 'MSGE_UN'),
#  ('003230_KS', 'STHO_UQ'),
#  ('003240_KS', 'CR_UN'),
#  ('003240_KS', 'KNF_UN'),
#  ('003240_KS', 'MSGE_UN'),
#  ('003240_KS', 'STHO_UQ'),
#  ('003410_KS', 'CR_UN'),
#  ('003410_KS', 'KNF_UN'),
#  ('003410_KS', 'MSGE_UN'),
#  ('003410_KS', 'STHO_UQ'),
#  ('003490_KS', 'CR_UN'),
#  ('003490_KS', 'KNF_UN'),
#  ('003490_KS', 'MSGE_UN'),
#  ('003490_KS', 'STHO_UQ'),
#  ('003550_KS', 'CR_UN'),
#  ('003550_KS', 'KNF_UN'),
#  ('003550_KS', 'MSGE_UN'),
#  ('003550_KS', 'STHO_UQ'),
#  ('003670_KS', 'CR_UN'),
#  ('003670_KS', 'KNF_UN'),
#  ('003670_KS', 'MSGE_UN'),
#  ('003670_KS', 'STHO_UQ'),
#  ('003850_KS', 'CR_UN'),
#  ('003850_KS', 'KNF_UN'),
#  ('003850_KS', 'MSGE_UN'),
#  ('003850_KS', 'STHO_UQ'),
#  ('004000_KS', 'CR_UN'),
#  ('004000_KS', 'KNF_UN'),
#  ('004000_KS', 'MSGE_UN'),
#  ('004000_KS', 'STHO_UQ'),
#  ('004020_KS', 'CR_UN'),
#  ('004020_KS', 'KNF_UN'),
#  ('004020_KS', 'MSGE_UN'),
#  ('004020_KS', 'STHO_UQ'),
#  ('004170_KS', 'CR_UN'),
#  ('004170_KS', 'KNF_UN'),
#  ('004170_KS', 'MSGE_UN'),
#  ('004170_KS', 'STHO_UQ'),
#  ('004370_KS', 'CR_UN'),
#  ('004370_KS', 'KNF_UN'),
#  ('004370_KS', 'MSGE_UN'),
#  ('004370_KS', 'STHO_UQ'),
#  ('004490_KS', 'CR_UN'),
#  ('004490_KS', 'KNF_UN'),
#  ('004490_KS', 'MSGE_UN'),
#  ('004490_KS', 'STHO_UQ'),
#  ('004800_KS', 'CR_UN'),
#  ('004800_KS', 'KNF_UN'),
#  ('004800_KS', 'MSGE_UN'),
#  ('004800_KS', 'STHO_UQ'),
#  ('004990_KS', 'CR_UN'),
#  ('004990_KS', 'KNF_UN'),
#  ('004990_KS', 'MSGE_UN'),
#  ('004990_KS', 'STHO_UQ'),
#  ('005250_KS', 'CR_UN'),
#  ('005250_KS', 'KNF_UN'),
#  ('005250_KS', 'MSGE_UN'),
#  ('005250_KS', 'STHO_UQ'),
#  ('005300_KS', 'CR_UN'),
#  ('005300_KS', 'KNF_UN'),
#  ('005300_KS', 'MSGE_UN'),
#  ('005300_KS', 'STHO_UQ'),
#  ('005380_KS', 'CR_UN'),
#  ('005380_KS', 'KNF_UN'),
#  ('005380_KS', 'MSGE_UN'),
#  ('005380_KS', 'STHO_UQ'),
#  ('005490_KS', 'CR_UN'),
#  ('005490_KS', 'KNF_UN'),
#  ('005490_KS', 'MSGE_UN'),
#  ('005490_KS', 'STHO_UQ'),
#  ('005830_KS', 'CR_UN'),
#  ('005830_KS', 'KNF_UN'),
#  ('005830_KS', 'MSGE_UN'),
#  ('005830_KS', 'STHO_UQ'),
#  ('005850_KS', 'CR_UN'),
#  ('005850_KS', 'KNF_UN'),
#  ('005850_KS', 'MSGE_UN'),
#  ('005850_KS', 'STHO_UQ'),
#  ('005930_KS', 'CR_UN'),
#  ('005930_KS', 'KNF_UN'),
#  ('005930_KS', 'MSGE_UN'),
#  ('005930_KS', 'STHO_UQ'),
#  ('005940_KS', 'CR_UN'),
#  ('005940_KS', 'KNF_UN'),
#  ('005940_KS', 'MSGE_UN'),
#  ('005940_KS', 'STHO_UQ'),
#  ('006040_KS', 'CR_UN'),
#  ('006040_KS', 'KNF_UN'),
#  ('006040_KS', 'MSGE_UN'),
#  ('006040_KS', 'STHO_UQ'),
#  ('006260_KS', 'CR_UN'),
#  ('006260_KS', 'KNF_UN'),
#  ('006260_KS', 'MSGE_UN'),
#  ('006260_KS', 'STHO_UQ'),
#  ('006280_KS', 'CR_UN'),
#  ('006280_KS', 'KNF_UN'),
#  ('006280_KS', 'MSGE_UN'),
#  ('006280_KS', 'STHO_UQ'),
#  ('006360_KS', 'CR_UN'),
#  ('006360_KS', 'KNF_UN'),
#  ('006360_KS', 'MSGE_UN'),
#  ('006360_KS', 'STHO_UQ'),
#  ('006400_KS', 'CR_UN'),
#  ('006400_KS', 'KNF_UN'),
#  ('006400_KS', 'MSGE_UN'),
#  ('006400_KS', 'STHO_UQ'),
#  ('006650_KS', 'CR_UN'),
#  ('006650_KS', 'KNF_UN'),
#  ('006650_KS', 'MSGE_UN'),
#  ('006650_KS', 'STHO_UQ'),
#  ('006800_KS', 'CR_UN'),
#  ('006800_KS', 'KNF_UN'),
#  ('006800_KS', 'MSGE_UN'),
#  ('006800_KS', 'STHO_UQ'),
#  ('007070_KS', 'CR_UN'),
#  ('007070_KS', 'KNF_UN'),
#  ('007070_KS', 'MSGE_UN'),
#  ('007070_KS', 'STHO_UQ'),
#  ('007310_KS', 'CR_UN'),
#  ('007310_KS', 'KNF_UN'),
#  ('007310_KS', 'MSGE_UN'),
#  ('007310_KS', 'STHO_UQ'),
#  ('008770_KS', 'CR_UN'),
#  ('008770_KS', 'KNF_UN'),
#  ('008770_KS', 'MSGE_UN'),
#  ('008770_KS', 'STHO_UQ'),
#  ('008930_KS', 'CR_UN'),
#  ('008930_KS', 'KNF_UN'),
#  ('008930_KS', 'MSGE_UN'),
#  ('008930_KS', 'STHO_UQ'),
#  ('009150_KS', 'CR_UN'),
#  ('009150_KS', 'KNF_UN'),
#  ('009150_KS', 'MSGE_UN'),
#  ('009150_KS', 'STHO_UQ'),
#  ('009240_KS', 'CR_UN'),
#  ('009240_KS', 'KNF_UN'),
#  ('009240_KS', 'MSGE_UN'),
#  ('009240_KS', 'STHO_UQ'),
#  ('009420_KS', 'CR_UN'),
#  ('009420_KS', 'KNF_UN'),
#  ('009420_KS', 'MSGE_UN'),
#  ('009420_KS', 'STHO_UQ'),
#  ('009540_KS', 'CR_UN'),
#  ('009540_KS', 'KNF_UN'),
#  ('009540_KS', 'MSGE_UN'),
#  ('009540_KS', 'STHO_UQ'),
#  ('009830_KS', 'CR_UN'),
#  ('009830_KS', 'KNF_UN'),
#  ('009830_KS', 'MSGE_UN'),
#  ('009830_KS', 'STHO_UQ'),
#  ('009900_KS', 'CR_UN'),
#  ('009900_KS', 'KNF_UN'),
#  ('009900_KS', 'MSGE_UN'),
#  ('009900_KS', 'STHO_UQ'),
#  ('010060_KS', 'CR_UN'),
#  ('010060_KS', 'KNF_UN'),
#  ('010060_KS', 'MSGE_UN'),
#  ('010060_KS', 'STHO_UQ'),
#  ('010120_KS', 'CR_UN'),
#  ('010120_KS', 'KNF_UN'),
#  ('010120_KS', 'MSGE_UN'),
#  ('010120_KS', 'STHO_UQ'),
#  ('010130_KS', 'CR_UN'),
#  ('010130_KS', 'KNF_UN'),
#  ('010130_KS', 'MSGE_UN'),
#  ('010130_KS', 'STHO_UQ'),
#  ('010140_KS', 'CR_UN'),
#  ('010140_KS', 'KNF_UN'),
#  ('010140_KS', 'MSGE_UN'),
#  ('010140_KS', 'STHO_UQ'),
#  ('010620_KS', 'CR_UN'),
#  ('010620_KS', 'KNF_UN'),
#  ('010620_KS', 'MSGE_UN'),
#  ('010620_KS', 'STHO_UQ'),
#  ('010780_KS', 'CR_UN'),
#  ('010780_KS', 'KNF_UN'),
#  ('010780_KS', 'MSGE_UN'),
#  ('010780_KS', 'STHO_UQ'),
#  ('010950_KS', 'CR_UN'),
#  ('010950_KS', 'KNF_UN'),
#  ('010950_KS', 'MSGE_UN'),
#  ('010950_KS', 'STHO_UQ'),
#  ('011070_KS', 'CR_UN'),
#  ('011070_KS', 'KNF_UN'),
#  ('011070_KS', 'MSGE_UN'),
#  ('011070_KS', 'STHO_UQ'),
#  ('011170_KS', 'CR_UN'),
#  ('011170_KS', 'KNF_UN'),
#  ('011170_KS', 'MSGE_UN'),
#  ('011170_KS', 'STHO_UQ'),
#  ('011200_KS', 'CR_UN'),
#  ('011200_KS', 'KNF_UN'),
#  ('011200_KS', 'MSGE_UN'),
#  ('011200_KS', 'STHO_UQ'),
#  ('011210_KS', 'CR_UN'),
#  ('011210_KS', 'KNF_UN'),
#  ('011210_KS', 'MSGE_UN'),
#  ('011210_KS', 'STHO_UQ'),
#  ('011780_KS', 'CR_UN'),
#  ('011780_KS', 'KNF_UN'),
#  ('011780_KS', 'MSGE_UN'),
#  ('011780_KS', 'STHO_UQ'),
#  ('011790_KS', 'CR_UN'),
#  ('011790_KS', 'KNF_UN'),
#  ('011790_KS', 'MSGE_UN'),
#  ('011790_KS', 'STHO_UQ'),
#  ('012330_KS', 'CR_UN'),
#  ('012330_KS', 'KNF_UN'),
#  ('012330_KS', 'MSGE_UN'),
#  ('012330_KS', 'STHO_UQ'),
#  ('012450_KS', 'CR_UN'),
#  ('012450_KS', 'KNF_UN'),
#  ('012450_KS', 'MSGE_UN'),
#  ('012450_KS', 'STHO_UQ'),
#  ('012750_KS', 'CR_UN'),
#  ('012750_KS', 'KNF_UN'),
#  ('012750_KS', 'MSGE_UN'),
#  ('012750_KS', 'STHO_UQ'),
#  ('013890_KS', 'CR_UN'),
#  ('013890_KS', 'KNF_UN'),
#  ('013890_KS', 'MSGE_UN'),
#  ('013890_KS', 'STHO_UQ'),
#  ('014680_KS', 'CR_UN'),
#  ('014680_KS', 'KNF_UN'),
#  ('014680_KS', 'MSGE_UN'),
#  ('014680_KS', 'STHO_UQ'),
#  ('014820_KS', 'CR_UN'),
#  ('014820_KS', 'KNF_UN'),
#  ('014820_KS', 'MSGE_UN'),
#  ('014820_KS', 'STHO_UQ'),
#  ('015760_KS', 'CR_UN'),
#  ('015760_KS', 'KNF_UN'),
#  ('015760_KS', 'MSGE_UN'),
#  ('015760_KS', 'STHO_UQ'),
#  ('016360_KS', 'CR_UN'),
#  ('016360_KS', 'KNF_UN'),
#  ('016360_KS', 'MSGE_UN'),
#  ('016360_KS', 'STHO_UQ'),
#  ('016380_KS', 'CR_UN'),
#  ('016380_KS', 'KNF_UN'),
#  ('016380_KS', 'MSGE_UN'),
#  ('016380_KS', 'STHO_UQ'),
#  ('017670_KS', 'CR_UN'),
#  ('017670_KS', 'KNF_UN'),
#  ('017670_KS', 'MSGE_UN'),
#  ('017670_KS', 'STHO_UQ'),
#  ('017800_KS', 'CR_UN'),
#  ('017800_KS', 'KNF_UN'),
#  ('017800_KS', 'MSGE_UN'),
#  ('017800_KS', 'STHO_UQ'),
#  ('018260_KS', 'CR_UN'),
#  ('018260_KS', 'KNF_UN'),
#  ('018260_KS', 'MSGE_UN'),
#  ('018260_KS', 'STHO_UQ'),
#  ('018880_KS', 'CR_UN'),
#  ('018880_KS', 'KNF_UN'),
#  ('018880_KS', 'MSGE_UN'),
#  ('018880_KS', 'STHO_UQ'),
#  ('019170_KS', 'CR_UN'),
#  ('019170_KS', 'KNF_UN'),
#  ('019170_KS', 'MSGE_UN'),
#  ('019170_KS', 'STHO_UQ'),
#  ('020000_KS', 'CR_UN'),
#  ('020000_KS', 'KNF_UN'),
#  ('020000_KS', 'MSGE_UN'),
#  ('020000_KS', 'STHO_UQ'),
#  ('020150_KS', 'CR_UN'),
#  ('020150_KS', 'KNF_UN'),
#  ('020150_KS', 'MSGE_UN'),
#  ('020150_KS', 'STHO_UQ'),
#  ('020560_KS', 'CR_UN'),
#  ('020560_KS', 'KNF_UN'),
#  ('020560_KS', 'MSGE_UN'),
#  ('020560_KS', 'STHO_UQ'),
#  ('021240_KS', 'CR_UN'),
#  ('021240_KS', 'KNF_UN'),
#  ('021240_KS', 'MSGE_UN'),
#  ('021240_KS', 'STHO_UQ'),
#  ('023530_KS', 'CR_UN'),
#  ('023530_KS', 'KNF_UN'),
#  ('023530_KS', 'MSGE_UN'),
#  ('023530_KS', 'STHO_UQ'),
#  ('024110_KS', 'CR_UN'),
#  ('024110_KS', 'KNF_UN'),
#  ('024110_KS', 'MSGE_UN'),
#  ('024110_KS', 'STHO_UQ'),
#  ('026960_KS', 'CR_UN'),
#  ('026960_KS', 'KNF_UN'),
#  ('026960_KS', 'MSGE_UN'),
#  ('026960_KS', 'STHO_UQ'),
#  ('028050_KS', 'CR_UN'),
#  ('028050_KS', 'KNF_UN'),
#  ('028050_KS', 'MSGE_UN'),
#  ('028050_KS', 'STHO_UQ'),
#  ('028260_KS', 'CR_UN'),
#  ('028260_KS', 'KNF_UN'),
#  ('028260_KS', 'MSGE_UN'),
#  ('028260_KS', 'STHO_UQ'),
#  ('028670_KS', 'CR_UN'),
#  ('028670_KS', 'KNF_UN'),
#  ('028670_KS', 'MSGE_UN'),
#  ('028670_KS', 'STHO_UQ'),
#  ('029780_KS', 'CR_UN'),
#  ('029780_KS', 'KNF_UN'),
#  ('029780_KS', 'MSGE_UN'),
#  ('029780_KS', 'STHO_UQ'),
#  ('030000_KS', 'CR_UN'),
#  ('030000_KS', 'KNF_UN'),
#  ('030000_KS', 'MSGE_UN'),
#  ('030000_KS', 'STHO_UQ'),
#  ('030200_KS', 'CR_UN'),
#  ('030200_KS', 'KNF_UN'),
#  ('030200_KS', 'MSGE_UN'),
#  ('030200_KS', 'STHO_UQ'),
#  ('031430_KS', 'CR_UN'),
#  ('031430_KS', 'KNF_UN'),
#  ('031430_KS', 'MSGE_UN'),
#  ('031430_KS', 'STHO_UQ'),
#  ('032350_KS', 'CR_UN'),
#  ('032350_KS', 'KNF_UN'),
#  ('032350_KS', 'MSGE_UN'),
#  ('032350_KS', 'STHO_UQ'),
#  ('032640_KS', 'CR_UN'),
#  ('032640_KS', 'KNF_UN'),
#  ('032640_KS', 'MSGE_UN'),
#  ('032640_KS', 'STHO_UQ'),
#  ('032830_KS', 'CR_UN'),
#  ('032830_KS', 'KNF_UN'),
#  ('032830_KS', 'MSGE_UN'),
#  ('032830_KS', 'STHO_UQ'),
#  ('033780_KS', 'CR_UN'),
#  ('033780_KS', 'KNF_UN'),
#  ('033780_KS', 'MSGE_UN'),
#  ('033780_KS', 'STHO_UQ'),
#  ('034020_KS', 'CALM_UW'),
#  ('034020_KS', 'CARA_UQ'),
#  ('034020_KS', 'CASS_UW'),
#  ('034020_KS', 'CATO_UN'),
#  ('034020_KS', 'CATY_UW'),
#  ('034020_KS', 'CBL_UN'),
#  ('034020_KS', 'CBNK_UW'),
#  ('034020_KS', 'CBZ_UN'),
#  ('034020_KS', 'CB_UN'),
#  ('034020_KS', 'CCBG_UW'),
#  ('034020_KS', 'CCB_UW'),
#  ('034020_KS', 'CCF_UA'),
#  ('034020_KS', 'CCI_UN'),
#  ('034020_KS', 'CCK_UN'),
#  ('034020_KS', 'CCL_UN'),
#  ('034020_KS', 'CCNE_UW'),
#  ('034020_KS', 'CCOI_UW'),
#  ('034020_KS', 'CCO_UN'),
#  ('034020_KS', 'CCRN_UW'),
#  ('034020_KS', 'CCSI_UW'),
#  ('034020_KS', 'CCS_UN'),
#  ('034020_KS', 'CC_UN'),
#  ('034020_KS', 'CDAY_UN'),
#  ('034020_KS', 'CDE_UN'),
#  ('034020_KS', 'CDLX_UQ'),
#  ('034020_KS', 'CDMO_UR'),
#  ('034020_KS', 'CDNA_UQ'),
#  ('034020_KS', 'CDNS_UW'),
#  ('034020_KS', 'CDRE_UN'),
#  ('034020_KS', 'CDW_UW'),
#  ('034020_KS', 'CDXS_UW'),
#  ('034020_KS', 'CEG_UW'),
#  ('034020_KS', 'CEIX_UN'),
#  ('034020_KS', 'CELH_UR'),
#  ('034020_KS', 'CELL_UW'),
#  ('034020_KS', 'CELU_UR'),
#  ('034020_KS', 'CENN_UR'),
#  ('034020_KS', 'CENTA_UW'),
#  ('034020_KS', 'CENT_UW'),
#  ('034020_KS', 'CENX_UW'),
#  ('034020_KS', 'CERE_UR'),
#  ('034020_KS', 'CERS_UQ'),
#  ('034020_KS', 'CERT_UW'),
#  ('034020_KS', 'CEVA_UW'),
#  ('034020_KS', 'CE_UN'),
#  ('034020_KS', 'CFB_UW'),
#  ('034020_KS', 'CFFN_UW'),
#  ('034020_KS', 'CFG_UN'),
#  ('034020_KS', 'CFLT_UW'),
#  ('034020_KS', 'CFR_UN'),
#  ('034020_KS', 'CF_UN'),
#  ('034020_KS', 'CGEM_UW'),
#  ('034020_KS', 'CGNX_UW'),
#  ('034020_KS', 'CG_UW'),
#  ('034020_KS', 'CHCO_UW'),
#  ('034020_KS', 'CHCT_UN'),
#  ('034020_KS', 'CHDN_UW'),
#  ('034020_KS', 'CHD_UN'),
#  ('034020_KS', 'CHEF_UW'),
#  ('034020_KS', 'CHE_UN'),
#  ('034020_KS', 'CHGG_UN'),
#  ('034020_KS', 'CHH_UN'),
#  ('034020_KS', 'CHK_UW'),
#  ('034020_KS', 'CHPT_UN'),
#  ('034020_KS', 'CHRD_UW'),
#  ('034020_KS', 'CHRS_UQ'),
#  ('034020_KS', 'CHRW_UW'),
#  ('034020_KS', 'CHS_UN'),
#  ('034020_KS', 'CHTR_UW'),
#  ('034020_KS', 'CHUY_UW'),
#  ('034020_KS', 'CHX_UW'),
#  ('034020_KS', 'CIEN_UN'),
#  ('034020_KS', 'CIFR_UW'),
#  ('034020_KS', 'CIM_UN'),
#  ('034020_KS', 'CINF_UW'),
#  ('034020_KS', 'CIO_UN'),
#  ('034020_KS', 'CIR_UN'),
#  ('034020_KS', 'CISO_UR'),
#  ('034020_KS', 'CIVB_UR'),
#  ('034020_KS', 'CIVI_UN'),
#  ('034020_KS', 'CIX_UA'),
#  ('034020_KS', 'CI_UN'),
#  ('034020_KS', 'CLAR_UW'),
#  ('034020_KS', 'CLBK_UW'),
#  ('034020_KS', 'CLDT_UN'),
#  ('034020_KS', 'CLDX_UR'),
#  ('034020_KS', 'CLFD_UQ'),
#  ('034020_KS', 'CLF_UN'),
#  ('034020_KS', 'CLH_UN'),
#  ('034020_KS', 'CLNE_UW'),
#  ('034020_KS', 'CLOV_UW'),
#  ('034020_KS', 'CLPR_UN'),
#  ('034020_KS', 'CLSK_UR'),
#  ('034020_KS', 'CLVT_UN'),
#  ('034020_KS', 'CLW_UN'),
#  ('034020_KS', 'CLX_UN'),
#  ('034020_KS', 'CL_UN'),
#  ('034020_KS', 'CMAX_UW'),
#  ('034020_KS', 'CMA_UN'),
#  ('034020_KS', 'CMBM_UQ'),
#  ('034020_KS', 'CMCO_UW'),
#  ('034020_KS', 'CMCSA_UW'),
#  ('034020_KS', 'CMC_UN'),
#  ('034020_KS', 'CME_UW'),
#  ('034020_KS', 'CMG_UN'),
#  ('034020_KS', 'CMI_UN'),
#  ('034020_KS', 'CMLS_UQ'),
#  ('034020_KS', 'CMPO_UQ'),
#  ('034020_KS', 'CMPR_UW'),
#  ('034020_KS', 'CMP_UN'),
#  ('034020_KS', 'CMRE_UN'),
#  ('034020_KS', 'CMRX_UQ'),
#  ('034020_KS', 'CMS_UN'),
#  ('034020_KS', 'CMTG_UN'),
#  ('034020_KS', 'CMTL_UW'),
#  ('034020_KS', 'CNA_UN'),
#  ('034020_KS', 'CNC_UN'),
#  ('034020_KS', 'CNDT_UW'),
#  ('034020_KS', 'CNK_UN'),
#  ('034020_KS', 'CNMD_UN'),
#  ('034020_KS', 'CNM_UN'),
#  ('034020_KS', 'CNNE_UN'),
#  ('034020_KS', 'CNOB_UW'),
#  ('034020_KS', 'CNO_UN'),
#  ('034020_KS', 'CNP_UN'),
#  ('034020_KS', 'CNSL_UW'),
#  ('034020_KS', 'CNS_UN'),
#  ('034020_KS', 'CNTY_UR'),
#  ('034020_KS', 'CNXC_UW'),
#  ('034020_KS', 'CNXN_UW'),
#  ('034020_KS', 'CNX_UN'),
#  ('034020_KS', 'COCO_UW'),
#  ('034020_KS', 'CODI_UN'),
#  ('034020_KS', 'COF_UN'),
#  ('034020_KS', 'COGT_UW'),
#  ('034020_KS', 'COHR_UN'),
#  ('034020_KS', 'COHU_UW'),
#  ('034020_KS', 'COIN_UW'),
#  ('034020_KS', 'COKE_UW'),
#  ('034020_KS', 'COLB_UW'),
#  ('034020_KS', 'COLD_UN'),
#  ('034020_KS', 'COLL_UW'),
#  ('034020_KS', 'COLM_UW'),
#  ('034020_KS', 'COMM_UW'),
#  ('034020_KS', 'COMP_UN'),
#  ('034020_KS', 'CONN_UW'),
#  ('034020_KS', 'COOK_UN'),
#  ('034020_KS', 'COOP_UR'),
#  ('034020_KS', 'COO_UN'),
#  ('034020_KS', 'COP_UN'),
#  ('034020_KS', 'CORT_UR'),
#  ('034020_KS', 'COST_UW'),
#  ('034020_KS', 'COTY_UN'),
#  ('034020_KS', 'COUR_UN'),
#  ('034020_KS', 'CPA_UN'),
#  ('034020_KS', 'CPB_UN'),
#  ('034020_KS', 'CPE_UN'),
#  ('034020_KS', 'CPF_UN'),
#  ('034020_KS', 'CPK_UN'),
#  ('034020_KS', 'CPRI_UN'),
#  ('034020_KS', 'CPRT_UW'),
#  ('034020_KS', 'CPRX_UR'),
#  ('034020_KS', 'CPSI_UW'),
#  ('034020_KS', 'CPSS_UQ'),
#  ('034020_KS', 'CPTN_UR'),
#  ('034020_KS', 'CPT_UN'),
#  ('034020_KS', 'CRAI_UW'),
#  ('034020_KS', 'CRBG_UN'),
#  ('034020_KS', 'CRBU_UW'),
#  ('034020_KS', 'CRC_UN'),
#  ('034020_KS', 'CRDO_UW'),
#  ('034020_KS', 'CRD_A_UN'),
#  ('034020_KS', 'CRGE_UQ'),
#  ('034020_KS', 'CRGY_UN'),
#  ('034020_KS', 'CRI_UN'),
#  ('034020_KS', 'CRK_UN'),
#  ('034020_KS', 'CRL_UN'),
#  ('034020_KS', 'CRMT_UW'),
#  ('034020_KS', 'CRM_UN'),
#  ('034020_KS', 'CRNC_UW'),
#  ('034020_KS', 'CRNX_UW'),
#  ('034020_KS', 'CROX_UW'),
#  ('034020_KS', 'CRSR_UW'),
#  ('034020_KS', 'CRS_UN'),
#  ('034020_KS', 'CRUS_UW'),
#  ('034020_KS', 'CRVL_UW'),
#  ('034020_KS', 'CRWD_UW'),
#  ('034020_KS', 'CR_UN'),
#  ('034020_KS', 'CSCO_UW'),
#  ('034020_KS', 'CSGP_UW'),
#  ('034020_KS', 'CSGS_UW'),
#  ('034020_KS', 'CSL_UN'),
#  ('034020_KS', 'CSR_UN'),
#  ('034020_KS', 'CSTE_UW'),
#  ('034020_KS', 'CSTL_UQ'),
#  ('034020_KS', 'CSTM_UN'),
#  ('034020_KS', 'CSTR_UW'),
#  ('034020_KS', 'CSV_UN'),
#  ('034020_KS', 'CSWI_UW'),
#  ('034020_KS', 'CSX_UW'),
#  ('034020_KS', 'CTAS_UW'),
#  ('034020_KS', 'CTBI_UW'),
#  ('034020_KS', 'CTIC_UR'),
#  ('034020_KS', 'CTKB_UW'),
#  ('034020_KS', 'CTLP_UW'),
#  ('034020_KS', 'CTLT_UN'),
#  ('034020_KS', 'CTOS_UN'),
#  ('034020_KS', 'CTO_UN'),
#  ('034020_KS', 'CTRA_UN'),
#  ('034020_KS', 'CTRE_UN'),
#  ('034020_KS', 'CTRN_UW'),
#  ('034020_KS', 'CTSH_UW'),
#  ('034020_KS', 'CTS_UN'),
#  ('034020_KS', 'CTVA_UN'),
#  ('034020_KS', 'CTV_UN'),
#  ('034020_KS', 'CUBE_UN'),
#  ('034020_KS', 'CUBI_UN'),
#  ('034020_KS', 'CURO_UN'),
#  ('034020_KS', 'CURV_UN'),
#  ('034020_KS', 'CUTR_UW'),
#  ('034020_KS', 'CUZ_UN'),
#  ('034020_KS', 'CVBF_UW'),
#  ('034020_KS', 'CVCO_UW'),
#  ('034020_KS', 'CVGW_UW'),
#  ('034020_KS', 'CVI_UN'),
#  ('034020_KS', 'CVLG_UW'),
#  ('034020_KS', 'CVLT_UW'),
#  ('034020_KS', 'CVNA_UN'),
#  ('034020_KS', 'CVS_UN'),
#  ('034020_KS', 'CVT_UQ'),
#  ('034020_KS', 'CVX_UN'),
#  ('034020_KS', 'CWEN_A_UN'),
#  ('034020_KS', 'CWEN_UN'),
#  ('034020_KS', 'CWH_UN'),
#  ('034020_KS', 'CWK_UN'),
#  ('034020_KS', 'CWST_UW'),
#  ('034020_KS', 'CWT_UN'),
#  ('034020_KS', 'CW_UN'),
#  ('034020_KS', 'CXT_UN'),
#  ('034020_KS', 'CXW_UN'),
#  ('034020_KS', 'CYH_UN'),
#  ('034020_KS', 'CYRX_UR'),
#  ('034020_KS', 'CYTK_UW'),
#  ('034020_KS', 'CYXT_UW'),
#  ('034020_KS', 'CZNC_UR'),
#  ('034020_KS', 'CZR_UW'),
#  ('034020_KS', 'C_UN'),
#  ('034020_KS', 'DAL_UN'),
#  ('034020_KS', 'DAN_UN'),
#  ('034020_KS', 'DAR_UN'),
#  ('034020_KS', 'DASH_UN'),
#  ('034020_KS', 'DAWN_UW'),
#  ('034020_KS', 'DBI_UN'),
#  ('034020_KS', 'DBRG_UN'),
#  ('034020_KS', 'DBX_UW'),
#  ('034020_KS', 'DCGO_UR'),
#  ('034020_KS', 'DCI_UN'),
#  ('034020_KS', 'DCOM_UW'),
#  ('034020_KS', 'DCO_UN'),
#  ('034020_KS', 'DCPH_UW'),
#  ('034020_KS', 'DC_UA'),
#  ('034020_KS', 'DDD_UN'),
#  ('034020_KS', 'DDOG_UW'),
#  ('034020_KS', 'DDS_UN'),
#  ('034020_KS', 'DD_UN'),
#  ('034020_KS', 'DEA_UN'),
#  ('034020_KS', 'DECK_UN'),
#  ('034020_KS', 'DEI_UN'),
#  ('034020_KS', 'DELL_UN'),
#  ('034020_KS', 'DENN_UR'),
#  ('034020_KS', 'DEN_UN'),
#  ('034020_KS', 'DE_UN'),
#  ('034020_KS', 'DFH_UN'),
#  ('034020_KS', 'DFIN_UN'),
#  ('034020_KS', 'DFS_UN'),
#  ('034020_KS', 'DGICA_UW'),
#  ('034020_KS', 'DGII_UW'),
#  ('034020_KS', 'DGX_UN'),
#  ('034020_KS', 'DG_UN'),
#  ('034020_KS', 'DHC_UW'),
#  ('034020_KS', 'DHIL_UW'),
#  ('034020_KS', 'DHI_UN'),
#  ('034020_KS', 'DHR_UN'),
#  ('034020_KS', 'DHT_UN'),
#  ('034020_KS', 'DHX_UN'),
#  ('034020_KS', 'DH_UW'),
#  ('034020_KS', 'DIBS_UQ'),
#  ('034020_KS', 'DICE_UQ'),
#  ('034020_KS', 'DINO_UN'),
#  ('034020_KS', 'DIN_UN'),
#  ('034020_KS', 'DIOD_UW'),
#  ('034020_KS', 'DISH_UW'),
#  ('034020_KS', 'DIS_UN'),
#  ('034020_KS', 'DJCO_UR'),
#  ('034020_KS', 'DKNG_UW'),
#  ('034020_KS', 'DKS_UN'),
#  ('034020_KS', 'DK_UN'),
#  ('034020_KS', 'DLB_UN'),
#  ('034020_KS', 'DLR_UN'),
#  ('034020_KS', 'DLTH_UW'),
#  ('034020_KS', 'DLTR_UW'),
#  ('034020_KS', 'DLX_UN'),
#  ('034020_KS', 'DMRC_UW'),
#  ('034020_KS', 'DM_UN'),
#  ('034020_KS', 'DNA_UN'),
#  ('034020_KS', 'DNB_UN'),
#  ('034020_KS', 'DNLI_UW'),
#  ('034020_KS', 'DNMR_UN'),
#  ('034020_KS', 'DNOW_UN'),
#  ('034020_KS', 'DNUT_UW'),
#  ('034020_KS', 'DOCN_UN'),
#  ('034020_KS', 'DOCS_UN'),
#  ('034020_KS', 'DOCU_UW'),
#  ('034020_KS', 'DOC_UN'),
#  ('034020_KS', 'DOMA_UN'),
#  ('034020_KS', 'DOMO_UQ'),
#  ('034020_KS', 'DOOR_UN'),
#  ('034020_KS', 'DORM_UW'),
#  ('034020_KS', 'DOUG_UN'),
#  ('034020_KS', 'DOV_UN'),
#  ('034020_KS', 'DOW_UN'),
#  ('034020_KS', 'DOX_UW'),
#  ('034020_KS', 'DO_UN'),
#  ('034020_KS', 'DPZ_UN'),
#  ('034020_KS', 'DRH_UN'),
#  ('034020_KS', 'DRI_UN'),
#  ('034020_KS', 'DRQ_UN'),
#  ('034020_KS', 'DRVN_UW'),
#  ('034020_KS', 'DSEY_UW'),
#  ('034020_KS', 'DSGN_UW'),
#  ('034020_KS', 'DSGR_UW'),
#  ('034020_KS', 'DSKE_UR'),
#  ('034020_KS', 'DSP_UW'),
#  ('034020_KS', 'DTC_UN'),
#  ('034020_KS', 'DTE_UN'),
#  ('034020_KS', 'DTM_UN'),
#  ('034020_KS', 'DT_UN'),
#  ('034020_KS', 'DUK_UN'),
#  ('034020_KS', 'DUOL_UW'),
#  ('034020_KS', 'DVAX_UW'),
#  ('034020_KS', 'DVA_UN'),
#  ('034020_KS', 'DVN_UN'),
#  ('034020_KS', 'DV_UN'),
#  ('034020_KS', 'DXCM_UW'),
#  ('034020_KS', 'DXC_UN'),
#  ('034020_KS', 'DXLG_UQ'),
#  ('034020_KS', 'DXPE_UW'),
#  ('034020_KS', 'DX_UN'),
#  ('034020_KS', 'DYN_UW'),
#  ('034020_KS', 'DY_UN'),
#  ('034020_KS', 'DZSI_UR'),
#  ('034020_KS', 'D_UN'),
#  ('034020_KS', 'EAF_UN'),
#  ('034020_KS', 'EAT_UN'),
#  ('034020_KS', 'EA_UW'),
#  ('034020_KS', 'EBAY_UW'),
#  ('034020_KS', 'EBC_UW'),
#  ('034020_KS', 'EBF_UN'),
#  ('034020_KS', 'EBIX_UW'),
#  ('034020_KS', 'EBS_UN'),
#  ('034020_KS', 'EBTC_UW'),
#  ('034020_KS', 'EB_UN'),
#  ('034020_KS', 'ECL_UN'),
#  ('034020_KS', 'ECPG_UW'),
#  ('034020_KS', 'ECVT_UN'),
#  ('034020_KS', 'EDIT_UW'),
#  ('034020_KS', 'ED_UN'),
#  ('034020_KS', 'EEFT_UW'),
#  ('034020_KS', 'EE_UN'),
#  ('034020_KS', 'EFC_UN'),
#  ('034020_KS', 'EFSC_UW'),
#  ('034020_KS', 'EFX_UN'),
#  ('034020_KS', 'EGAN_UR'),
#  ('034020_KS', 'EGBN_UR'),
#  ('034020_KS', 'EGHT_UW'),
#  ('034020_KS', 'EGIO_UW'),
#  ('034020_KS', 'EGLE_UN'),
#  ('034020_KS', 'EGP_UN'),
#  ('034020_KS', 'EGRX_UQ'),
#  ('034020_KS', 'EGY_UN'),
#  ('034020_KS', 'EHAB_UN'),
#  ('034020_KS', 'EHC_UN'),
#  ('034020_KS', 'EHTH_UW'),
#  ('034020_KS', 'EIGR_UQ'),
#  ('034020_KS', 'EIG_UN'),
#  ('034020_KS', 'EIX_UN'),
#  ('034020_KS', 'ELAN_UN'),
#  ('034020_KS', 'ELF_UN'),
#  ('034020_KS', 'ELME_UN'),
#  ('034020_KS', 'ELS_UN'),
#  ('034020_KS', 'ELV_UN'),
#  ('034020_KS', 'EL_UN'),
#  ('034020_KS', 'EMBC_UW'),
#  ('034020_KS', 'EME_UN'),
#  ('034020_KS', 'EMN_UN'),
#  ('034020_KS', 'EMR_UN'),
#  ('034020_KS', 'ENFN_UN'),
#  ('034020_KS', 'ENOB_UR'),
#  ('034020_KS', 'ENOV_UN'),
#  ('034020_KS', 'ENPH_UQ'),
#  ('034020_KS', 'ENR_UN'),
#  ('034020_KS', 'ENSG_UW'),
#  ('034020_KS', 'ENS_UN'),
#  ('034020_KS', 'ENTA_UW'),
#  ('034020_KS', 'ENTG_UW'),
#  ('034020_KS', 'ENVA_UN'),
#  ('034020_KS', 'ENVX_UW'),
#  ('034020_KS', 'ENV_UN'),
#  ('034020_KS', 'EOG_UN'),
#  ('034020_KS', 'EOLS_UQ'),
#  ('034020_KS', 'EPAC_UN'),
#  ('034020_KS', 'EPAM_UN'),
#  ('034020_KS', 'EPC_UN'),
#  ('034020_KS', 'EPRT_UN'),
#  ('034020_KS', 'EPR_UN'),
#  ('034020_KS', 'EP_UA'),
#  ('034020_KS', 'EQBK_UN'),
#  ('034020_KS', 'EQC_UN'),
#  ('034020_KS', 'EQH_UN'),
#  ('034020_KS', 'EQIX_UW'),
#  ('034020_KS', 'EQRX_UQ'),
#  ('034020_KS', 'EQR_UN'),
#  ('034020_KS', 'EQT_UN'),
#  ('034020_KS', 'ERAS_UW'),
#  ('034020_KS', 'ERIE_UW'),
#  ('034020_KS', 'ERII_UW'),
#  ('034020_KS', 'ESAB_UN'),
#  ('034020_KS', 'ESE_UN'),
#  ('034020_KS', 'ESGR_UW'),
#  ('034020_KS', 'ESI_UN'),
#  ('034020_KS', 'ESMT_UN'),
#  ('034020_KS', 'ESNT_UN'),
#  ('034020_KS', 'ESPR_UQ'),
#  ('034020_KS', 'ESQ_UR'),
#  ('034020_KS', 'ESRT_UN'),
#  ('034020_KS', 'ESS_UN'),
#  ('034020_KS', 'ESTC_UN'),
#  ('034020_KS', 'ESTE_UN'),
#  ('034020_KS', 'ES_UN'),
#  ('034020_KS', 'ETD_UN'),
#  ('034020_KS', 'ETN_UN'),
#  ('034020_KS', 'ETRN_UN'),
#  ('034020_KS', 'ETR_UN'),
#  ('034020_KS', 'ETSY_UW'),
#  ('034020_KS', 'ETWO_UN'),
#  ('034020_KS', 'EVA_UN'),
#  ('034020_KS', 'EVBG_UQ'),
#  ('034020_KS', 'EVCM_UW'),
#  ('034020_KS', 'EVC_UN'),
#  ('034020_KS', 'EVER_UQ'),
#  ('034020_KS', 'EVGO_UW'),
#  ('034020_KS', 'EVH_UN'),
#  ('034020_KS', 'EVLV_UR'),
#  ('034020_KS', 'EVRG_UW'),
#  ('034020_KS', 'EVRI_UN'),
#  ('034020_KS', 'EVR_UN'),
#  ('034020_KS', 'EVTC_UN'),
#  ('034020_KS', 'EWBC_UW'),
#  ('034020_KS', 'EWCZ_UW'),
#  ('034020_KS', 'EWTX_UW'),
#  ('034020_KS', 'EW_UN'),
#  ('034020_KS', 'EXAS_UR'),
#  ('034020_KS', 'EXC_UW'),
#  ('034020_KS', 'EXEL_UW'),
#  ('034020_KS', 'EXLS_UW'),
#  ('034020_KS', 'EXPD_UW'),
#  ('034020_KS', 'EXPE_UW'),
#  ('034020_KS', 'EXPI_UQ'),
#  ('034020_KS', 'EXPO_UW'),
#  ('034020_KS', 'EXPR_UN'),
#  ('034020_KS', 'EXP_UN'),
#  ('034020_KS', 'EXR_UN'),
#  ('034020_KS', 'EXTR_UW'),
#  ('034020_KS', 'EYE_UW'),
#  ('034020_KS', 'EYPT_UQ'),
#  ('034020_KS', 'EZPW_UW'),
#  ('034020_KS', 'FAF_UN'),
#  ('034020_KS', 'FANG_UW'),
#  ('034020_KS', 'FARO_UW'),
#  ('034020_KS', 'FAST_UW'),
#  ('034020_KS', 'FATE_UQ'),
#  ('034020_KS', 'FATH_UN'),
#  ('034020_KS', 'FA_UW'),
#  ('034020_KS', 'FBIN_UN'),
#  ('034020_KS', 'FBIZ_UW'),
#  ('034020_KS', 'FBK_UN'),
#  ('034020_KS', 'FBMS_UQ'),
#  ('034020_KS', 'FBNC_UW'),
#  ('034020_KS', 'FBP_UN'),
#  ('034020_KS', 'FBRT_UN'),
#  ('034020_KS', 'FCBC_UW'),
#  ('034020_KS', 'FCEL_UQ'),
#  ('034020_KS', 'FCFS_UW'),
#  ('034020_KS', 'FCF_UN'),
#  ('034020_KS', 'FCNCA_UW'),
#  ('034020_KS', 'FCN_UN'),
#  ('034020_KS', 'FCPT_UN'),
#  ('034020_KS', 'FCUV_UQ'),
#  ('034020_KS', 'FCX_UN'),
#  ('034020_KS', 'FC_UN'),
#  ('034020_KS', 'FDMT_UW'),
#  ('034020_KS', 'FDP_UN'),
#  ('034020_KS', 'FDS_UN'),
#  ('034020_KS', 'FDX_UN'),
#  ('034020_KS', 'FEAM_UW'),
#  ('034020_KS', 'FELE_UW'),
#  ('034020_KS', 'FE_UN'),
#  ('034020_KS', 'FFBC_UW'),
#  ('034020_KS', 'FFIC_UW'),
#  ('034020_KS', 'FFIE_UR'),
#  ('034020_KS', 'FFIN_UW'),
#  ('034020_KS', 'FFIV_UW'),
#  ('034020_KS', 'FFWM_UQ'),
#  ('034020_KS', 'FF_UN'),
#  ('034020_KS', 'FGBI_UQ'),
#  ('034020_KS', 'FGEN_UW'),
#  ('034020_KS', 'FG_UN'),
#  ('034020_KS', 'FHB_UW'),
#  ('034020_KS', 'FHI_UN'),
#  ('034020_KS', 'FHN_UN'),
#  ('034020_KS', 'FHTX_UQ'),
#  ('034020_KS', 'FIBK_UW'),
#  ('034020_KS', 'FICO_UN'),
#  ('034020_KS', 'FIGS_UN'),
#  ('034020_KS', 'FISI_UW'),
#  ('034020_KS', 'FISV_UW'),
#  ('034020_KS', 'FIS_UN'),
#  ('034020_KS', 'FITB_UW'),
#  ('034020_KS', 'FIVE_UW'),
#  ('034020_KS', 'FIVN_UQ'),
#  ('034020_KS', 'FIX_UN'),
#  ('034020_KS', 'FIZZ_UW'),
#  ('034020_KS', 'FLGT_UQ'),
#  ('034020_KS', 'FLIC_UR'),
#  ('034020_KS', 'FLL_UR'),
#  ('034020_KS', 'FLNC_UW'),
#  ('034020_KS', 'FLNG_UN'),
#  ('034020_KS', 'FLO_UN'),
#  ('034020_KS', 'FLR_UN'),
#  ('034020_KS', 'FLS_UN'),
#  ('034020_KS', 'FLT_UN'),
#  ('034020_KS', 'FLWS_UW'),
#  ('034020_KS', 'FLYW_UW'),
#  ('034020_KS', 'FL_UN'),
#  ('034020_KS', 'FMAO_UR'),
#  ('034020_KS', 'FMBH_UQ'),
#  ('034020_KS', 'FMC_UN'),
#  ('034020_KS', 'FMNB_UR'),
#  ('034020_KS', 'FNA_UN'),
#  ('034020_KS', 'FNB_UN'),
#  ('034020_KS', 'FND_UN'),
#  ('034020_KS', 'FNF_UN'),
#  ('034020_KS', 'FNKO_UW'),
#  ('034020_KS', 'FNLC_UW'),
#  ('034020_KS', 'FN_UN'),
#  ('034020_KS', 'FOA_UN'),
#  ('034020_KS', 'FOCS_UW'),
#  ('034020_KS', 'FOLD_UQ'),
#  ('034020_KS', 'FORG_UN'),
#  ('034020_KS', 'FORM_UW'),
#  ('034020_KS', 'FORR_UW'),
#  ('034020_KS', 'FOR_UN'),
#  ('034020_KS', 'FOSL_UW'),
#  ('034020_KS', 'FOUR_UN'),
#  ('034020_KS', 'FOXA_UW'),
#  ('034020_KS', 'FOXF_UW'),
#  ('034020_KS', 'FOX_UW'),
#  ('034020_KS', 'FPI_UN'),
#  ...]

# %%
len(qw)
